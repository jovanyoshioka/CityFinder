# %%
import pandas as pd

# %%
def add_char(string, char, position): 
    # Convert the string to a list of characters 
    string_list = list(string) 
     
    # Insert the character at the specified position 
    string_list.insert(position, str(char)) 
    
    
    #string_list = str(string_list)
    # Join the list back into a string 
    new_string = "".join(string_list)
     
    return new_string

# %%
for i in range(len(taxes.STATEFIPS)): 
    if len(taxes.STATEFIPS[i]) != 2:
        
        taxes.STATEFIPS[i] = add_char(taxes.STATEFIPS[i],0,0)
        
    else: 
        taxes.STATEFIPS[i] = taxes.STATEFIPS[i]

# %%
for i in range(len(taxes.COUNTYFIPS)):
    if len(taxes.COUNTYFIPS[i]) == 1:
        taxes.COUNTYFIPS[i] = add_char(taxes.COUNTYFIPS[i],0,0)
        taxes.COUNTYFIPS[i] = add_char(taxes.COUNTYFIPS[i],0,0)
    elif len(taxes.COUNTYFIPS[i]) == 2: 
        taxes.COUNTYFIPS[i] = add_char(taxes.COUNTYFIPS[i],0,0)
    else:
        taxes.COUNTYFIPS[i] = taxes.COUNTYFIPS[i]

# %% [markdown]
# ### Taxes

# %%
taxes = pd.read_csv("21incyallnoagi.csv", encoding='ISO-8859-1' )

# %%
taxes.STATEFIPS = taxes.STATEFIPS.astype('string')
taxes.COUNTYFIPS = taxes.COUNTYFIPS.astype('string')

# %%
#the 
taxes = taxes[["STATEFIPS", "STATE", "COUNTYNAME", "COUNTYFIPS",
            "N1", "A00100", "A02650", "A18425",
             "A18450", "A18500", "A18800", "A18300", "A10600", "FIPS"]]
taxes
# Out:
#      STATEFIPS STATE         COUNTYNAME COUNTYFIPS         N1       A00100  \
# 0            1    AL            Alabama          0  2162210.0  154268214.0
# 1            1    AL     Autauga County          1    25720.0    1688218.0
# 2            1    AL     Baldwin County          3   111140.0    9360157.0
# 3            1    AL     Barbour County          5     9740.0     448442.0
# 4            1    AL        Bibb County          7     8230.0     533851.0
# ...        ...   ...                ...        ...        ...          ...
# 3189        56    WY  Sweetwater County         37    19530.0    1427418.0
# 3190        56    WY       Teton County         39    14860.0    9561613.0
# 3191        56    WY       Uinta County         41     9350.0     673690.0
# 3192        56    WY    Washakie County         43     3790.0     263135.0
# 3193        56    WY      Weston County         45     3190.0     215820.0
#
# ...

# %%
for i in range(len(taxes.STATEFIPS)): 
    if len(taxes.STATEFIPS[i]) != 2:
        
        taxes.STATEFIPS[i] = add_char(taxes.STATEFIPS[i],0,0)
        
    else: 
        taxes.STATEFIPS[i] = taxes.STATEFIPS[i]
# Out:
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_24589/82657768.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taxes.STATEFIPS[i] = add_char(taxes.STATEFIPS[i],0,0)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_24589/82657768.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taxes.STATEFIPS[i] = taxes.STATEFIPS[i]

# %%
for i in range(len(taxes.COUNTYFIPS)):
    if len(taxes.COUNTYFIPS[i]) == 1:
        taxes.COUNTYFIPS[i] = add_char(taxes.COUNTYFIPS[i],0,0)
        taxes.COUNTYFIPS[i] = add_char(taxes.COUNTYFIPS[i],0,0)
    elif len(taxes.COUNTYFIPS[i]) == 2: 
        taxes.COUNTYFIPS[i] = add_char(taxes.COUNTYFIPS[i],0,0)
    else:
        taxes.COUNTYFIPS[i] = taxes.COUNTYFIPS[i]
# Out:
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_24589/2075747355.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taxes.COUNTYFIPS[i] = add_char(taxes.COUNTYFIPS[i],0,0)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_24589/2075747355.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taxes.COUNTYFIPS[i] = add_char(taxes.COUNTYFIPS[i],0,0)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_24589/2075747355.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
taxes["FIPS"] = taxes["STATEFIPS"] + taxes["COUNTYFIPS"]
taxes
# Out:
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_24589/3509328504.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taxes["FIPS"] = taxes["STATEFIPS"] + taxes["COUNTYFIPS"]
#      STATEFIPS STATE         COUNTYNAME COUNTYFIPS         N1       A00100  \
# 0           01    AL            Alabama        000  2162210.0  154268214.0
# 1           01    AL     Autauga County        001    25720.0    1688218.0
# 2           01    AL     Baldwin County        003   111140.0    9360157.0
# 3           01    AL     Barbour County        005     9740.0     448442.0
# 4           01    AL        Bibb County        007     8230.0     533851.0
# ...        ...   ...                ...        ...        ...          ...
# ...

# %%
taxes = taxes.rename(columns={"COUNTYNAME":"COUNTY","N1":"Num_Returns",
                             "A00100":"adj_gross_income", "A02650":"total_income",
                              "A18425": "st_local_income_tax","A18450":"st_local_gen_sales_tax", 
                              "A18500":"realestate_tax", "A18800":"personal_prop_tax", 
                              "A18300":"total_taxes_paid", "A10600":"total_tax_payments_amt"})
taxes
# Out:
#      STATEFIPS STATE             COUNTY COUNTYFIPS  Num_Returns  \
# 0           01    AL            Alabama        000    2162210.0
# 1           01    AL     Autauga County        001      25720.0
# 2           01    AL     Baldwin County        003     111140.0
# 3           01    AL     Barbour County        005       9740.0
# 4           01    AL        Bibb County        007       8230.0
# ...        ...   ...                ...        ...          ...
# 3189        56    WY  Sweetwater County        037      19530.0
# 3190        56    WY       Teton County        039      14860.0
# 3191        56    WY       Uinta County        041       9350.0
# 3192        56    WY    Washakie County        043       3790.0
# 3193        56    WY      Weston County        045       3190.0
#
#       adj_gross_income  total_income  st_local_income_tax  \
# 0          154268214.0  1.555913e+08            1357554.0
# 1            1688218.0  1.700226e+06               8910.0
# ...

# %%
taxes["YEAR"] = 2021

# %%
taxes
# Out:
#      STATEFIPS STATE             COUNTY COUNTYFIPS  Num_Returns  \
# 0           01    AL            Alabama        000    2162210.0
# 1           01    AL     Autauga County        001      25720.0
# 2           01    AL     Baldwin County        003     111140.0
# 3           01    AL     Barbour County        005       9740.0
# 4           01    AL        Bibb County        007       8230.0
# ...        ...   ...                ...        ...          ...
# 3189        56    WY  Sweetwater County        037      19530.0
# 3190        56    WY       Teton County        039      14860.0
# 3191        56    WY       Uinta County        041       9350.0
# 3192        56    WY    Washakie County        043       3790.0
# 3193        56    WY      Weston County        045       3190.0
#
#       adj_gross_income  total_income  st_local_income_tax  \
# 0          154268214.0  1.555913e+08            1357554.0
# 1            1688218.0  1.700226e+06               8910.0
# ...

# %% [markdown]
# ### TAXES IS DONE

# %% [markdown]
# bls total of all industries

# %%
bls = pd.read_csv("BLS 2022 counties.csv")
bls.head(30)
# Out:
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_24589/78868750.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   bls = pd.read_csv("BLS 2022 counties.csv")
#    area_fips  own_code  industry_code  agglvl_code  size_code  year qtr  \
# 0       1000         0             10           50          0  2022   A
# 1       1000         1             10           51          0  2022   A
# 2       1000         2             10           51          0  2022   A
# 3       1000         3             10           51          0  2022   A
# 4       1000         5             10           51          0  2022   A
# 5       1000         8             10           96          0  2022   A
# 6       1001         0             10           70          0  2022   A
# 7       1001         1             10           71          0  2022   A
# 8       1001         2             10           71          0  2022   A
# ...

# %%
lg101 = pd.read_csv("local_gov101.csv")

# %%
lg101= lg101[["area_fips", "own_code", "industry_code", "agglvl_code", "year",
              "annual_avg_estabs", "annual_avg_emplvl", "total_annual_wages", 
              "annual_avg_wkly_wage", "avg_annual_pay"]]
lg101
# Out:
#      area_fips  own_code  industry_code  agglvl_code  year  annual_avg_estabs  \
# 0        01000         3            101           52  2022                  6
# 1        01000         5            101           52  2022              20117
# 2        01001         5            101           72  2022                161
# 3        01003         5            101           72  2022               1192
# 4        01005         5            101           72  2022                 85
# ...        ...       ...            ...          ...   ...                ...
# 6687     C4974         5            101           42  2022                753
# 6688     US000         1            101           12  2022                137
# 6689     US000         2            101           12  2022               1921
# 6690     US000         3            101           12  2022               4393
# 6691     US000         5            101           12  2022            1427867
#
# ...

# %%
lg101.dtypes
# Out:
# area_fips               object
# own_code                 int64
# industry_code            int64
# agglvl_code              int64
# year                     int64
# annual_avg_estabs        int64
# annual_avg_emplvl        int64
# total_annual_wages       int64
# annual_avg_wkly_wage     int64
# avg_annual_pay           int64
# dtype: object

# %%
lg102.dtypes
# Out:
# area_fips               object
# own_code                 int64
# industry_code            int64
# agglvl_code              int64
# year                     int64
# annual_avg_estabs        int64
# annual_avg_emplvl        int64
# total_annual_wages       int64
# annual_avg_wkly_wage     int64
# avg_annual_pay           int64
# dtype: object

# %%
combo = lg102.merge(lg101, how="outer", on="area_fips", suffixes=("102",""))
combo
# Out:
#       area_fips  own_code102  industry_code102  agglvl_code102  year102  \
# 0         01000            1               102              52     2022
# 1         01000            1               102              52     2022
# 2         01000            2               102              52     2022
# 3         01000            2               102              52     2022
# 4         01000            3               102              52     2022
# ...         ...          ...               ...             ...      ...
# 25429     US000            3               102              12     2022
# 25430     US000            5               102              12     2022
# 25431     US000            5               102              12     2022
# 25432     US000            5               102              12     2022
# 25433     US000            5               102              12     2022
#
#        annual_avg_estabs102  annual_avg_emplvl102  total_annual_wages102  \
# ...

# %%
lg101
# Out:
# area_fips               object
# own_code                 int64
# industry_code            int64
# agglvl_code              int64
# year                     int64
# annual_avg_estabs        int64
# annual_avg_emplvl        int64
# total_annual_wages       int64
# annual_avg_wkly_wage     int64
# avg_annual_pay           int64
# dtype: object

# %%
for i in range(len(lg101.area_fips)):
    string_list = list(lg101.area_fips[i])
    if string_list[-3:] == ["0","0","0"]: 
        lg101 = lg101.drop([i])
        
    else: 
        lg101 = lg101
     # Join the list back into a string 
    lg101.area_fips[i] = "".join(string_list)
# Out:
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_24589/885540710.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_24589/885540710.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_24589/885540710.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
for i in range(len(lg102.area_fips)):
    string_list = list(lg102.area_fips[i])
    if string_list[-3:] == ["0","0","0"]: 
        lg102 = lg102.drop([i])
        
    else: 
        lg102 = lg102
     # Join the list back into a string 
    lg102.area_fips[i] = "".join(string_list)
# Out:
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_24589/276528851.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_24589/276528851.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_24589/276528851.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
attempt = lg102.join(lg101, how="outer", lsuffix="102")
attempt
# Out:
#       area_fips102  own_code102  industry_code102  agglvl_code102  year102  \
# 2              NaN          NaN               NaN             NaN      NaN
# 3              NaN          NaN               NaN             NaN      NaN
# 4            01001          1.0             102.0            72.0   2022.0
# 5            01001          2.0             102.0            72.0   2022.0
# 6            01001          3.0             102.0            72.0   2022.0
# ...            ...          ...               ...             ...      ...
# 13590        C4942          5.0             102.0            42.0   2022.0
# 13591        C4962          5.0             102.0            42.0   2022.0
# 13592        C4966          5.0             102.0            42.0   2022.0
# 13593        C4970          5.0             102.0            42.0   2022.0
# 13594        C4974          5.0             102.0            42.0   2022.0
#
# ...

# %%
# Out:
#       area_fips  own_code  industry_code  agglvl_code  year  \
# 4         01001         1            102           72  2022
# 5         01001         2            102           72  2022
# 6         01001         3            102           72  2022
# 7         01001         5            102           72  2022
# 8         01003         1            102           72  2022
# ...         ...       ...            ...          ...   ...
# 13590     C4942         5            102           42  2022
# 13591     C4962         5            102           42  2022
# 13592     C4966         5            102           42  2022
# 13593     C4970         5            102           42  2022
# 13594     C4974         5            102           42  2022
#
#        annual_avg_estabs  annual_avg_emplvl  total_annual_wages  \
# 4                     10                 87             5562233
# 5                     18                579            34704754
# ...

# %%
la = lg102.set_index("area_fips")
lo = lg101.set_index("area_fips")
fr = la.join(lo, lsuffix="haha", how= "outer")
fr
# Out:
#            own_codehaha  industry_codehaha  agglvl_codehaha  yearhaha  \
# area_fips
# 01000                 1                102               52      2022
# 01000                 1                102               52      2022
# 01000                 2                102               52      2022
# 01000                 2                102               52      2022
# 01000                 3                102               52      2022
# ...                 ...                ...              ...       ...
# US000                 3                102               12      2022
# US000                 5                102               12      2022
# US000                 5                102               12      2022
# US000                 5                102               12      2022
# US000                 5                102               12      2022
#
#            annual_avg_estabshaha  annual_avg_emplvlhaha  \
# area_fips
# ...

# %%
second = lg102.set_index("area_fips")
first = lg101.set_index("area_fips")
combo = second.join(first, lsuffix="102", how="outer")

# %%
combo = combo[["own_code102", "agglvl_code102", "annual_avg_estabs102", "annual_avg_emplvl102",
        "total_annual_wages102", "avg_annual_pay102", "own_code", "industry_code", 
        "agglvl_code", "year", "annual_avg_estabs", "annual_avg_emplvl", "total_annual_wages",
        "avg_annual_pay"]]
combo
# Out:
#            own_code102  agglvl_code102  annual_avg_estabs102  \
# area_fips
# 01000                1              52                  1257
# 01000                1              52                  1257
# 01000                2              52                  1392
# 01000                2              52                  1392
# 01000                3              52                  3744
# ...                ...             ...                   ...
# US000                3              12                167249
# US000                5              12               9787801
# US000                5              12               9787801
# US000                5              12               9787801
# US000                5              12               9787801
#
#            annual_avg_emplvl102  total_annual_wages102  avg_annual_pay102  \
# area_fips
# 01000                     55220             5050209651              91456
# ...

# %%
third = lg1011.set_index("area_fips")
fourth = lg1012.set_index("area_fips")
fifth = lg1013.set_index("area_fips")
sixth = lg1021.set_index("area_fips")
seventh = lg1022.set_index("area_fips")
eighth = lg1023.set_index("area_fips")
ninth = lg1024.set_index("area_fips")
tenth = lg1025.set_index("area_fips")
eleventh = lg1026.set_index("area_fips")
twelfth = lg1027.set_index("area_fips")
thirteenth = lg1028.set_index("area_fips")
fourteenth = lg1029.set_index("area_fips")

# %%
combo = third.join(combo, lsuffix="1011", how="outer")
combo = combo[["own_code1011", "agglvl_code1011", "annual_avg_estabs1011", "annual_avg_emplvl1011",
        "total_annual_wages1011", "avg_annual_pay1011","own_code102", "agglvl_code102", "annual_avg_estabs102", "annual_avg_emplvl102",
        "total_annual_wages102", "avg_annual_pay102", "own_code", "industry_code", 
        "agglvl_code", "year", "annual_avg_estabs", "annual_avg_emplvl", "total_annual_wages",
        "avg_annual_pay"]]
# Out:
#            own_code1011  agglvl_code1011  annual_avg_estabs1011  \
# area_fips
# 01000               5.0             53.0                 1918.0
# 01000               5.0             53.0                 1918.0
# 01000               5.0             53.0                 1918.0
# 01000               5.0             53.0                 1918.0
# 01000               5.0             53.0                 1918.0
# ...                 ...              ...                    ...
# US000               5.0             13.0               143341.0
# US000               5.0             13.0               143341.0
# US000               5.0             13.0               143341.0
# US000               5.0             13.0               143341.0
# US000               5.0             13.0               143341.0
#
#            annual_avg_emplvl1011  total_annual_wages1011  avg_annual_pay1011  \
# area_fips
# 01000                    17272.0            1.118383e+09             64753.0
# ...

# %%
combo = fourth.join(combo, lsuffix="1012", how="outer")
combo = combo[["own_code1012", "agglvl_code1012", "annual_avg_estabs1012", "annual_avg_emplvl1012",
        "total_annual_wages1012", "avg_annual_pay1012","own_code1011", "agglvl_code1011", "annual_avg_estabs1011", "annual_avg_emplvl1011",
        "total_annual_wages1011", "avg_annual_pay1011","own_code102", "agglvl_code102", "annual_avg_estabs102", "annual_avg_emplvl102",
        "total_annual_wages102", "avg_annual_pay102", "own_code", "industry_code", 
        "agglvl_code", "year", "annual_avg_estabs", "annual_avg_emplvl", "total_annual_wages",
        "avg_annual_pay"]]

# %%
combo = fifth.join(combo, lsuffix="1013", how="outer")
combo = combo[["own_code1013", "agglvl_code1013", "annual_avg_estabs1013", "annual_avg_emplvl1013",
        "total_annual_wages1013", "avg_annual_pay1013","own_code1012", "agglvl_code1012", "annual_avg_estabs1012", "annual_avg_emplvl1012",
        "total_annual_wages1012", "avg_annual_pay1012","own_code1011", "agglvl_code1011", "annual_avg_estabs1011", "annual_avg_emplvl1011",
        "total_annual_wages1011", "avg_annual_pay1011","own_code102", "agglvl_code102", "annual_avg_estabs102", "annual_avg_emplvl102",
        "total_annual_wages102", "avg_annual_pay102", "own_code", "industry_code", 
        "agglvl_code", "year", "annual_avg_estabs", "annual_avg_emplvl", "total_annual_wages",
        "avg_annual_pay"]]

# %%
combo = fifth.join(combo, lsuffix="1021", how="outer")
combo = combo[["own_code1021", "agglvl_code1021", "annual_avg_estabs1021", "annual_avg_emplvl1021",
        "total_annual_wages1021", "avg_annual_pay1021","own_code1013", "agglvl_code1013", "annual_avg_estabs1013", "annual_avg_emplvl1013",
        "total_annual_wages1013", "avg_annual_pay1013","own_code1012", "agglvl_code1012", "annual_avg_estabs1012", "annual_avg_emplvl1012",
        "total_annual_wages1012", "avg_annual_pay1012","own_code1011", "agglvl_code1011", "annual_avg_estabs1011", "annual_avg_emplvl1011",
        "total_annual_wages1011", "avg_annual_pay1011","own_code102", "agglvl_code102", "annual_avg_estabs102", "annual_avg_emplvl102",
        "total_annual_wages102", "avg_annual_pay102", "own_code", "industry_code", 
        "agglvl_code", "year", "annual_avg_estabs", "annual_avg_emplvl", "total_annual_wages",
        "avg_annual_pay"]]

# %%
combo = sixth.join(combo, lsuffix="1022", how="outer")
combo = combo[["own_code1022", "agglvl_code1022", "annual_avg_estabs1022", "annual_avg_emplvl1022",
        "total_annual_wages1022", "avg_annual_pay1022","own_code1021", "agglvl_code1021", "annual_avg_estabs1021", "annual_avg_emplvl1021",
        "total_annual_wages1021", "avg_annual_pay1021","own_code1013", "agglvl_code1013", "annual_avg_estabs1013", "annual_avg_emplvl1013",
        "total_annual_wages1013", "avg_annual_pay1013","own_code1012", "agglvl_code1012", "annual_avg_estabs1012", "annual_avg_emplvl1012",
        "total_annual_wages1012", "avg_annual_pay1012","own_code1011", "agglvl_code1011", "annual_avg_estabs1011", "annual_avg_emplvl1011",
        "total_annual_wages1011", "avg_annual_pay1011","own_code102", "agglvl_code102", "annual_avg_estabs102", "annual_avg_emplvl102",
        "total_annual_wages102", "avg_annual_pay102", "own_code", "industry_code", 
        "agglvl_code", "year", "annual_avg_estabs", "annual_avg_emplvl", "total_annual_wages",
        "avg_annual_pay"]]

# %%
combo = seventh.join(combo, lsuffix="1023", how="outer")
combo = combo[["own_code1023", "agglvl_code1023", "annual_avg_estabs1023", "annual_avg_emplvl1023",
        "total_annual_wages1023", "avg_annual_pay1023","own_code1022", "agglvl_code1022", "annual_avg_estabs1022", "annual_avg_emplvl1022",
        "total_annual_wages1022", "avg_annual_pay1022","own_code1021", "agglvl_code1021", "annual_avg_estabs1021", "annual_avg_emplvl1021",
        "total_annual_wages1021", "avg_annual_pay1021","own_code1013", "agglvl_code1013", "annual_avg_estabs1013", "annual_avg_emplvl1013",
        "total_annual_wages1013", "avg_annual_pay1013","own_code1012", "agglvl_code1012", "annual_avg_estabs1012", "annual_avg_emplvl1012",
        "total_annual_wages1012", "avg_annual_pay1012","own_code1011", "agglvl_code1011", "annual_avg_estabs1011", "annual_avg_emplvl1011",
        "total_annual_wages1011", "avg_annual_pay1011","own_code102", "agglvl_code102", "annual_avg_estabs102", "annual_avg_emplvl102",
        "total_annual_wages102", "avg_annual_pay102", "own_code", "industry_code", 
        "agglvl_code", "year", "annual_avg_estabs", "annual_avg_emplvl", "total_annual_wages",
        "avg_annual_pay"]]

# %%
combo = eighth.join(combo, lsuffix="1024", how="outer")
combo = combo[["own_code1024", "agglvl_code1024", "annual_avg_estabs1024", "annual_avg_emplvl1024",
        "total_annual_wages1024", "avg_annual_pay1024","own_code1023", "agglvl_code1023", "annual_avg_estabs1023", "annual_avg_emplvl1023",
        "total_annual_wages1023", "avg_annual_pay1023","own_code1022", "agglvl_code1022", "annual_avg_estabs1022", "annual_avg_emplvl1022",
        "total_annual_wages1022", "avg_annual_pay1022","own_code1021", "agglvl_code1021", "annual_avg_estabs1021", "annual_avg_emplvl1021",
        "total_annual_wages1021", "avg_annual_pay1021","own_code1013", "agglvl_code1013", "annual_avg_estabs1013", "annual_avg_emplvl1013",
        "total_annual_wages1013", "avg_annual_pay1013","own_code1012", "agglvl_code1012", "annual_avg_estabs1012", "annual_avg_emplvl1012",
        "total_annual_wages1012", "avg_annual_pay1012","own_code1011", "agglvl_code1011", "annual_avg_estabs1011", "annual_avg_emplvl1011",
        "total_annual_wages1011", "avg_annual_pay1011","own_code102", "agglvl_code102", "annual_avg_estabs102", "annual_avg_emplvl102",
        "total_annual_wages102", "avg_annual_pay102", "own_code", "industry_code", 
        "agglvl_code", "year", "annual_avg_estabs", "annual_avg_emplvl", "total_annual_wages",
        "avg_annual_pay"]]

# %%
# Out:
#            own_code1024  agglvl_code1024  annual_avg_estabs1024  \
# area_fips
# 01000               1.0             53.0                   20.0
# 01000               1.0             53.0                   20.0
# 01000               1.0             53.0                   20.0
# 01000               1.0             53.0                   20.0
# 01000               1.0             53.0                   20.0
# ...                 ...              ...                    ...
# US000               5.0             13.0              1034057.0
# US000               5.0             13.0              1034057.0
# US000               5.0             13.0              1034057.0
# US000               5.0             13.0              1034057.0
# US000               5.0             13.0              1034057.0
#
#            annual_avg_emplvl1024  total_annual_wages1024  avg_annual_pay1024  \
# area_fips
# 01000                      135.0            1.277728e+07             94998.0
# ...

# %%
lg102 = pd.read_csv("local_gov102.csv")

# %%
lg102 = lg102[["area_fips", "own_code", "industry_code", "agglvl_code", "year",
              "annual_avg_estabs", "annual_avg_emplvl", "total_annual_wages", 
              "annual_avg_wkly_wage", "avg_annual_pay"]]
lg102
# Out:
#       area_fips  own_code  industry_code  agglvl_code  year  \
# 0         01000         1            102           52  2022
# 1         01000         2            102           52  2022
# 2         01000         3            102           52  2022
# 3         01000         5            102           52  2022
# 4         01001         1            102           72  2022
# ...         ...       ...            ...          ...   ...
# 13594     C4974         5            102           42  2022
# 13595     US000         1            102           12  2022
# 13596     US000         2            102           12  2022
# 13597     US000         3            102           12  2022
# 13598     US000         5            102           12  2022
#
#        annual_avg_estabs  annual_avg_emplvl  total_annual_wages  \
# 0                   1257              55220          5050209651
# 1                   1392              96718          6102839680
# ...

# %%
lg1011 = pd.read_csv("local_gov1011.csv")
lg1011= lg1011[["area_fips", "own_code", "industry_code", "agglvl_code", "year",
              "annual_avg_estabs", "annual_avg_emplvl", "total_annual_wages", 
              "annual_avg_wkly_wage", "avg_annual_pay"]]

# %%
lg1012 = pd.read_csv("local_gov1012.csv")
lg1012= lg1012[["area_fips", "own_code", "industry_code", "agglvl_code", "year",
              "annual_avg_estabs", "annual_avg_emplvl", "total_annual_wages", 
              "annual_avg_wkly_wage", "avg_annual_pay"]]
lg1013 = pd.read_csv("local_gov1013.csv")
lg1013= lg1013[["area_fips", "own_code", "industry_code", "agglvl_code", "year",
              "annual_avg_estabs", "annual_avg_emplvl", "total_annual_wages", 
              "annual_avg_wkly_wage", "avg_annual_pay"]]
lg1021 = pd.read_csv("local_gov1021.csv")
lg1021= lg1021[["area_fips", "own_code", "industry_code", "agglvl_code", "year",
              "annual_avg_estabs", "annual_avg_emplvl", "total_annual_wages", 
              "annual_avg_wkly_wage", "avg_annual_pay"]]
lg1022 = pd.read_csv("local_gov1022.csv")
lg1022= lg1022[["area_fips", "own_code", "industry_code", "agglvl_code", "year",
              "annual_avg_estabs", "annual_avg_emplvl", "total_annual_wages", 
              "annual_avg_wkly_wage", "avg_annual_pay"]]
lg1023 = pd.read_csv("local_gov1023.csv")
lg1023= lg1023[["area_fips", "own_code", "industry_code", "agglvl_code", "year",
              "annual_avg_estabs", "annual_avg_emplvl", "total_annual_wages", 
              "annual_avg_wkly_wage", "avg_annual_pay"]]
lg1024 = pd.read_csv("local_gov1024.csv")
lg1024= lg1024[["area_fips", "own_code", "industry_code", "agglvl_code", "year",
              "annual_avg_estabs", "annual_avg_emplvl", "total_annual_wages", 
              "annual_avg_wkly_wage", "avg_annual_pay"]]
lg1025 = pd.read_csv("local_gov1025.csv")
lg1025= lg1025[["area_fips", "own_code", "industry_code", "agglvl_code", "year",
              "annual_avg_estabs", "annual_avg_emplvl", "total_annual_wages", 
              "annual_avg_wkly_wage", "avg_annual_pay"]]
lg1026 = pd.read_csv("local_gov1026.csv")
lg1026= lg1026[["area_fips", "own_code", "industry_code", "agglvl_code", "year",
              "annual_avg_estabs", "annual_avg_emplvl", "total_annual_wages", 
              "annual_avg_wkly_wage", "avg_annual_pay"]]
lg1027 = pd.read_csv("local_gov1027.csv")
lg1027= lg1027[["area_fips", "own_code", "industry_code", "agglvl_code", "year",
              "annual_avg_estabs", "annual_avg_emplvl", "total_annual_wages", 
              "annual_avg_wkly_wage", "avg_annual_pay"]]
lg1028 = pd.read_csv("local_gov1028.csv")
lg1028= lg1028[["area_fips", "own_code", "industry_code", "agglvl_code", "year",
              "annual_avg_estabs", "annual_avg_emplvl", "total_annual_wages", 
              "annual_avg_wkly_wage", "avg_annual_pay"]]
lg1029 = pd.read_csv("local_gov1029.csv")
lg1029= lg1029[["area_fips", "own_code", "industry_code", "agglvl_code", "year",
              "annual_avg_estabs", "annual_avg_emplvl", "total_annual_wages", 
              "annual_avg_wkly_wage", "avg_annual_pay"]]

# %%
# Out:
#      area_fips  own_code  industry_code  agglvl_code  year  annual_avg_estabs  \
# 0        01000         5           1029           53  2022                 14
# 1        01069         5           1029           73  2022                  0
# 2        01073         5           1029           73  2022                  1
# 3        01089         5           1029           73  2022                  1
# 4        01101         5           1029           73  2022                  0
# ...        ...       ...            ...          ...   ...                ...
# 2151     C4974         5           1029           43  2022                109
# 2152     US000         1           1029           13  2022                  6
# 2153     US000         2           1029           13  2022                 91
# 2154     US000         3           1029           13  2022                178
# 2155     US000         5           1029           13  2022             346089
#
# ...
