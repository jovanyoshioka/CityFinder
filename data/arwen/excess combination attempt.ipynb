# %% [markdown]
# ### Combining my data

# %%
import pandas as pd

# %% [markdown]
# ### NOT FINISHED
# Crime data & info

# %%
crime = pd.read_csv("Table_6_Crime_in_the_United_States_by_Metropolitan_Statistical_Area_2019.csv", encoding='ISO-8859-1')

# %% [markdown]
# ### NOT FINISHED
# bls info

# %%
bls = pd.read_csv("bls 2022.csv")
bls
# Out:
#      area_fips  own_code industry_code  agglvl_code  size_code  year qtr  \
# 0        US000         0            10           10          0  2022   A
# 1        US000         1            10           11          0  2022   A
# 2        US000         1           101           12          0  2022   A
# 3        US000         1          1011           13          0  2022   A
# 4        US000         1          1012           13          0  2022   A
# ...        ...       ...           ...          ...        ...   ...  ..
# 4459     US000         5          9999           16          0  2022   A
# 4460     US000         5         99999           17          0  2022   A
# 4461     US000         5        999999           18          0  2022   A
# 4462     US000         8            10           95          0  2022   A
# 4463     US000         9            10           94          0  2022   A
#
#      disclosure_code  annual_avg_estabs  annual_avg_emplvl  ...  \
# ...

# %%
#getting rid of unneeded columns 

bls = bls.drop("qtr", axis=1)
bls = bls.drop("disclosure_code", axis=1)
bls = bls.drop("size_code", axis=1)
bls = bls.drop("oty_avg_annual_pay_pct_chg", axis=1)
bls = bls.drop("oty_avg_annual_pay_chg", axis=1)
bls = bls.drop("oty_annual_avg_wkly_wage_pct_chg", axis=1)
bls = bls.drop("oty_annual_avg_wkly_wage_chg", axis=1)
bls = bls.drop("oty_annual_contributions_pct_chg", axis=1)
bls = bls.drop("oty_annual_contributions_chg", axis=1)
bls = bls.drop("oty_taxable_annual_wages_pct_chg", axis=1)
bls = bls.drop("oty_taxable_annual_wages_chg", axis=1)
bls = bls.drop("oty_total_annual_wages_pct_chg", axis=1)
bls = bls.drop("oty_total_annual_wages_chg", axis=1)
bls = bls.drop("lq_total_annual_wages", axis=1)
bls = bls.drop("lq_taxable_annual_wages", axis=1)
bls = bls.drop("lq_annual_contributions", axis=1)
bls = bls.drop("lq_annual_avg_wkly_wage", axis=1)
bls = bls.drop("lq_avg_annual_pay", axis=1)
bls = bls.drop("oty_disclosure_code", axis=1)
bls = bls.drop("oty_annual_avg_estabs_chg", axis=1)
bls = bls.drop("oty_annual_avg_estabs_pct_chg", axis=1)
bls = bls.drop("oty_annual_avg_emplvl_chg", axis=1)
bls = bls.drop("oty_annual_avg_emplvl_pct_chg", axis=1)
bls = bls.drop("lq_disclosure_code", axis=1)
bls = bls.drop("lq_annual_avg_estabs", axis=1)
bls = bls.drop("lq_annual_avg_emplvl", axis=1)
bls
# Out:
#      area_fips  own_code industry_code  agglvl_code  year  annual_avg_estabs  \
# 0        US000         0            10           10  2022           11519312
# 1        US000         1            10           11  2022              60876
# 2        US000         1           101           12  2022                137
# 3        US000         1          1011           13  2022                 74
# 4        US000         1          1012           13  2022                  1
# ...        ...       ...           ...          ...   ...                ...
# 4459     US000         5          9999           16  2022             346089
# 4460     US000         5         99999           17  2022             346089
# 4461     US000         5        999999           18  2022             346089
# 4462     US000         8            10           95  2022             303644
# 4463     US000         9            10           94  2022           11458436
#
# ...

# %%
bls = bls.rename()

# %%
bls["lq_taxable_annual_wages"].value_counts()
# Out:
# 1.0    3059
# 0.0    1405
# Name: lq_taxable_annual_wages, dtype: int64

# %%
#some ones that are already by fips

# %%
taxes = pd.read_csv("21incyallnoagi.csv", encoding='ISO-8859-1' )

# %%
taxes.head(10)
taxes.dtypes

# %%
taxes.STATEFIPS = taxes.STATEFIPS.astype('string')
taxes.STATEFIPS.dtypes
# Out:
# string[python]

# %%
taxes.COUNTYFIPS = taxes.COUNTYFIPS.astype('string')
taxes.COUNTYFIPS.dtypes
# Out:
# string[python]

# %%
taxes.dtypes

# %%
type(taxes.STATEFIPS)

# %%
def add_char(string, char, position): 
    # Convert the string to a list of characters 
    string_list = list(string) 
     
    # Insert the character at the specified position 
    string_list.insert(position, str(char)) 
    
    
    #string_list = str(string_list)
    # Join the list back into a string 
    new_string = "".join(string_list)
     
    return new_string 


for i in range(len(taxes.STATEFIPS)): 
    if len(taxes.STATEFIPS[i]) != 2:
        
        taxes.STATEFIPS[i] = add_char(taxes.STATEFIPS[i],0,0)
        
    else: 
        taxes.STATEFIPS[i] = taxes.STATEFIPS[i]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_19344/1115766253.py in <module>
#      14
#      15
# ---> 16 for i in range(len(taxes.STATEFIPS)):
#      17     if len(taxes.STATEFIPS[i]) != 2:
#      18
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'STATEFIPS'

# %%
def add_char(string, char, position): 
    # Convert the string to a list of characters 
    string_list = list(string) 
     
    # Insert the character at the specified position 
    string_list.insert(position, str(char)) 
    
    
    #string_list = str(string_list)
    # Join the list back into a string 
    new_string = "".join(string_list)
     
    return new_string

# %%
for i in range(len(taxes.COUNTYFIPS)):
    if len(taxes.COUNTYFIPS[i]) == 1:
        taxes.COUNTYFIPS[i] = add_char(taxes.COUNTYFIPS[i],0,0)
        taxes.COUNTYFIPS[i] = add_char(taxes.COUNTYFIPS[i],0,0)
    elif len(taxes.COUNTYFIPS[i]) == 2: 
        taxes.COUNTYFIPS[i] = add_char(taxes.COUNTYFIPS[i],0,0)
    else:
        taxes.COUNTYFIPS[i] = taxes.COUNTYFIPS[i]

# %%
taxes["FIPS"] =

# %%
len(taxes.STATEFIPS[1])

# %%
taxes.head(10)
# Out:
#   STATEFIPS STATE COUNTYFIPS       COUNTYNAME  AGI_STUB         N1     MARS1  \
# 0        01    AL        000          Alabama         0  2162210.0  981380.0
# 1        01    AL        001   Autauga County         0    25720.0   10900.0
# 2        01    AL        003   Baldwin County         0   111140.0   48700.0
# 3        01    AL        005   Barbour County         0     9740.0    4670.0
# 4        01    AL        007      Bibb County         0     8230.0    3520.0
# 5        01    AL        009    Blount County         0    24110.0    9740.0
# 6        01    AL        011   Bullock County         0     4100.0    2030.0
# 7        01    AL        013    Butler County         0     8100.0    3610.0
# 8        01    AL        015   Calhoun County         0    49290.0   22620.0
# 9        01    AL        017  Chambers County         0    14200.0    6730.0
#
#       MARS2     MARS4        ELF  ...   N85300    A85300    N11901     A11901  \
# ...

# %%
taxes["FIPS"] = taxes["STATEFIPS"] + taxes["COUNTYFIPS"]
taxes.head()
# Out:
#   STATEFIPS STATE COUNTYFIPS      COUNTYNAME  AGI_STUB         N1     MARS1  \
# 0        01    AL        000         Alabama         0  2162210.0  981380.0
# 1        01    AL        001  Autauga County         0    25720.0   10900.0
# 2        01    AL        003  Baldwin County         0   111140.0   48700.0
# 3        01    AL        005  Barbour County         0     9740.0    4670.0
# 4        01    AL        007     Bibb County         0     8230.0    3520.0
#
#       MARS2     MARS4        ELF  ...    A85300    N11901     A11901  \
# 0  749170.0  380920.0  2034110.0  ...  344964.0  462370.0  3221102.0
# 1   10000.0    4100.0    24070.0  ...    1339.0    5750.0    26814.0
# 2   46360.0   12960.0   103370.0  ...   21990.0   30730.0   275297.0
# 3    2650.0    2220.0     8930.0  ...     548.0    1560.0     9341.0
# 4    3050.0    1510.0     7580.0  ...     104.0    1350.0     4626.0
#
#       N11900     A11900     N11902     A11902   N12000    A12000   FIPS
# ...

# %%
taxes = taxes[["FIPS", "N1", "A00100", "N02650", "A02650", 
               "A04450", "A04100", "N18425", "A18425","N18450", "A18450", 
                "N18500", "A18500", "N18800", "A18800", "N18460", "A18460", "N18300", 
                "A18300", "N19300", "A19300", "N19500", "A19500", "N09400", "A09400",
               "N85530", "A85530", "N85300", "A85300", "N11901", "A11901", "N11900", 
               "A11900", "N11902", "A11902", "N12000", "A12000"]]

                    
taxes.head()
# Out:
#     FIPS         N1       A00100     N02650        A02650      A04450  \
# 0  01000  2162210.0  154268214.0  2127200.0  1.555913e+08  35426482.0
# 1  01001    25720.0    1688218.0    25380.0  1.700226e+06    437709.0
# 2  01003   111140.0    9360157.0   109850.0  9.458767e+06   1852613.0
# 3  01005     9740.0     448442.0     9380.0  4.521740e+05    156638.0
# 4  01007     8230.0     533851.0     7880.0  5.365300e+05    140582.0
#
#        A04100    N18425     A18425   N18450  ...   N85300    A85300    N11901  \
# 0  34697859.0  120800.0  1357554.0  24020.0  ...  57180.0  344964.0  462370.0
# 1    429338.0    1250.0     8910.0    250.0  ...    430.0    1339.0    5750.0
# 2   1801934.0    6950.0    80172.0   1640.0  ...   4260.0   21990.0   30730.0
# 3    153198.0     240.0     1776.0     80.0  ...    130.0     548.0    1560.0
# 4    138171.0     250.0     2441.0     60.0  ...     60.0     104.0    1350.0
#
#       A11901     N11900     A11900     N11902     A11902   N12000    A12000
# ...

# %%
  taxes["A02650"]/taxes["N1"]
# Out:
# 0        71.959401
# 1        66.105210
# 2        85.106775
# 3        46.424435
# 4        65.191981
#            ...
# 3189     73.442243
# 3190    647.542194
# 3191     72.472193
# 3192     69.972823
# 3193     68.263323
# Length: 3194, dtype: float64

# %%
taxes.shape
# Out:
# (3194, 37)

# %%
fun = taxes.join()

# %%
# ?join()
result = left.join(right, on="key")
# Out:
# Object `join()` not found.

# %%
blss = pd.read_csv("BLS 2022 counties.csv")
blss.head(30)
# Out:
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_19344/1608051047.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   blss = pd.read_csv("BLS 2022 counties.csv")
#    area_fips  own_code  industry_code  agglvl_code  size_code  year qtr  \
# 0       1000         0             10           50          0  2022   A
# 1       1000         1             10           51          0  2022   A
# 2       1000         2             10           51          0  2022   A
# 3       1000         3             10           51          0  2022   A
# 4       1000         5             10           51          0  2022   A
# 5       1000         8             10           96          0  2022   A
# 6       1001         0             10           70          0  2022   A
# 7       1001         1             10           71          0  2022   A
# 8       1001         2             10           71          0  2022   A
# ...

# %%
blss.area_fips = blss.area_fips.astype("string")

# %%
hospitals = pd.read_csv("Hospital_General_Information.csv")
hospitals.head()
# Out:
#   Facility ID                    Facility Name                     Address  \
# 0      010001  SOUTHEAST HEALTH MEDICAL CENTER      1108 ROSS CLARK CIRCLE
# 1      010005         MARSHALL MEDICAL CENTERS  2505 U S HIGHWAY 431 NORTH
# 2      010006     NORTH ALABAMA MEDICAL CENTER         1701 VETERANS DRIVE
# 3      010007         MIZELL MEMORIAL HOSPITAL               702 N MAIN ST
# 4      010008      CRENSHAW COMMUNITY HOSPITAL         101 HOSPITAL CIRCLE
#
#   City/Town State  ZIP Code County/Parish Telephone Number  \
# 0    DOTHAN    AL     36301       HOUSTON   (334) 793-8701
# 1      BOAZ    AL     35957      MARSHALL   (256) 593-8310
# 2  FLORENCE    AL     35630    LAUDERDALE   (256) 629-1000
# 3       OPP    AL     36467     COVINGTON   (334) 493-3541
# 4   LUVERNE    AL     36049      CRENSHAW   (334) 335-3374
#
#           Hospital Type                           Hospital Ownership  ...  \
# 0  Acute Care Hospitals  Government - Hospital District or Authority  ...
# ...

# %%
hospitals = hospitals[["Address", "City/Town", "State", "ZIP Code", 
                       "County/Parish", "Emergency Services"]]
hospitals.head()
# Out:
#                       Address City/Town State  ZIP Code County/Parish  \
# 0      1108 ROSS CLARK CIRCLE    DOTHAN    AL     36301       HOUSTON
# 1  2505 U S HIGHWAY 431 NORTH      BOAZ    AL     35957      MARSHALL
# 2         1701 VETERANS DRIVE  FLORENCE    AL     35630    LAUDERDALE
# 3               702 N MAIN ST       OPP    AL     36467     COVINGTON
# 4         101 HOSPITAL CIRCLE   LUVERNE    AL     36049      CRENSHAW
#
#   Emergency Services
# 0                Yes
# 1                Yes
# 2                Yes
# 3                Yes
# 4                Yes

# %%
hospitals["ZIP"] = hospitals["ZIP Code"]
hospitals.head(20)
# Out:
#                          Address   City/Town State  ZIP Code County/Parish  \
# 0         1108 ROSS CLARK CIRCLE      DOTHAN    AL     36301       HOUSTON
# 1     2505 U S HIGHWAY 431 NORTH        BOAZ    AL     35957      MARSHALL
# 2            1701 VETERANS DRIVE    FLORENCE    AL     35630    LAUDERDALE
# 3                  702 N MAIN ST         OPP    AL     36467     COVINGTON
# 4            101 HOSPITAL CIRCLE     LUVERNE    AL     36049      CRENSHAW
# 5     50 MEDICAL PARK EAST DRIVE  BIRMINGHAM    AL     35235     JEFFERSON
# 6           200 MED CENTER DRIVE  FORT PAYNE    AL     35968       DE KALB
# 7        1000 FIRST STREET NORTH   ALABASTER    AL     35007        SHELBY
# 8   1720 UNIVERSITY BLVD STE 305  BIRMINGHAM    AL     35233     JEFFERSON
# 9   1300 SOUTH MONTGOMERY AVENUE   SHEFFIELD    AL     35660       COLBERT
# 10              126 HOSPITAL AVE       OZARK    AL     36360          DALE
# ...

# %%
fips = pd.read_csv("ZIP-COUNTY-FIPS_2017-06.csv")
fips.head()
# Out:
#      ZIP      COUNTYNAME STATE  STCOUNTYFP CLASSFP
# 0  36003  Autauga County    AL        1001      H1
# 1  36006  Autauga County    AL        1001      H1
# 2  36067  Autauga County    AL        1001      H1
# 3  36066  Autauga County    AL        1001      H1
# 4  36703  Autauga County    AL        1001      H1

# %%
fips.STCOUNTYFP = fips.STCOUNTYFP.astype("string")

fips.dtypes
# Out:
# ZIP            int64
# COUNTYNAME    object
# STATE         object
# STCOUNTYFP    string
# CLASSFP       object
# join          string
# dtype: object

# %%
for i in range(len(fips.STCOUNTYFP)): 
    if len(fips.STCOUNTYFP[i]) != 5:
        
        fips.STCOUNTYFP[i] = add_char(fips.STCOUNTYFP[i],0,0)
        
    else: 
        fips.STCOUNTYFP[i] = fips.STCOUNTYFP[i]

# %%
fips.head(30)
# Out:
#       ZIP      COUNTYNAME STATE STCOUNTYFP CLASSFP  join
# 0   36003  Autauga County    AL      01001      H1  1001
# 1   36006  Autauga County    AL      01001      H1  1001
# 2   36067  Autauga County    AL      01001      H1  1001
# 3   36066  Autauga County    AL      01001      H1  1001
# 4   36703  Autauga County    AL      01001      H1  1001
# 5   36701  Autauga County    AL      01001      H1  1001
# 6   36091  Autauga County    AL      01001      H1  1001
# 7   36051  Autauga County    AL      01001      H1  1001
# 8   36068  Autauga County    AL      01001      H1  1001
# 9   36008  Autauga County    AL      01001      H1  1001
# 10  36022  Autauga County    AL      01001      H1  1001
# 11  36749  Autauga County    AL      01001      H1  1001
# 12  36758  Autauga County    AL      01001      H1  1001
# 13  36550  Baldwin County    AL      01003      H1  1003
# 14  36551  Baldwin County    AL      01003      H1  1003
# ...

# %%
# Out:
#       ZIP      COUNTYNAME STATE STCOUNTYFP CLASSFP  join
# 0   36003  Autauga County    AL      01001      H1  1001
# 1   36006  Autauga County    AL      01001      H1  1001
# 2   36067  Autauga County    AL      01001      H1  1001
# 3   36066  Autauga County    AL      01001      H1  1001
# 4   36703  Autauga County    AL      01001      H1  1001
# 5   36701  Autauga County    AL      01001      H1  1001
# 6   36091  Autauga County    AL      01001      H1  1001
# 7   36051  Autauga County    AL      01001      H1  1001
# 8   36068  Autauga County    AL      01001      H1  1001
# 9   36008  Autauga County    AL      01001      H1  1001
# 10  36022  Autauga County    AL      01001      H1  1001
# 11  36749  Autauga County    AL      01001      H1  1001
# 12  36758  Autauga County    AL      01001      H1  1001
# 13  36550  Baldwin County    AL      01003      H1  1003
# 14  36551  Baldwin County    AL      01003      H1  1003
# ...

# %%
combo = hospitals.join(fips.set_index(["ZIP"]),on="ZIP",rsuffix="ugh")
combo.head(30)
# Out:
#                          Address   City/Town State  ZIP Code County/Parish  \
# 0         1108 ROSS CLARK CIRCLE      DOTHAN    AL     36301       HOUSTON
# 0         1108 ROSS CLARK CIRCLE      DOTHAN    AL     36301       HOUSTON
# 1     2505 U S HIGHWAY 431 NORTH        BOAZ    AL     35957      MARSHALL
# 1     2505 U S HIGHWAY 431 NORTH        BOAZ    AL     35957      MARSHALL
# 1     2505 U S HIGHWAY 431 NORTH        BOAZ    AL     35957      MARSHALL
# 1     2505 U S HIGHWAY 431 NORTH        BOAZ    AL     35957      MARSHALL
# 2            1701 VETERANS DRIVE    FLORENCE    AL     35630    LAUDERDALE
# 3                  702 N MAIN ST         OPP    AL     36467     COVINGTON
# 3                  702 N MAIN ST         OPP    AL     36467     COVINGTON
# 3                  702 N MAIN ST         OPP    AL     36467     COVINGTON
# 4            101 HOSPITAL CIRCLE     LUVERNE    AL     36049      CRENSHAW
# ...
