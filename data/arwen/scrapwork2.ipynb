# %%
import pandas as pd
import numpy as np

# %%
def add_char(string, char, position): 
    # Convert the string to a list of characters 
    string_list = list(string) 
     
    # Insert the character at the specified position 
    string_list.insert(position, str(char)) 
    
    
    #string_list = str(string_list)
    # Join the list back into a string 
    new_string = "".join(string_list)
     
    return new_string

# %%
#Taxes

taxes = pd.read_csv("21incyallnoagi.csv", encoding='ISO-8859-1' )

taxes.STATEFIPS = taxes.STATEFIPS.astype('string')
taxes.COUNTYFIPS = taxes.COUNTYFIPS.astype('string')
 

for i in range(len(taxes.STATEFIPS)): 
    if len(taxes.STATEFIPS[i]) != 2:
        
        taxes.STATEFIPS[i] = add_char(taxes.STATEFIPS[i],0,0)
        
    else: 
        taxes.STATEFIPS[i] = taxes.STATEFIPS[i]
        
        
        
for i in range(len(taxes.COUNTYFIPS)):
    if len(taxes.COUNTYFIPS[i]) == 1:
        taxes.COUNTYFIPS[i] = add_char(taxes.COUNTYFIPS[i],0,0)
        taxes.COUNTYFIPS[i] = add_char(taxes.COUNTYFIPS[i],0,0)
    elif len(taxes.COUNTYFIPS[i]) == 2: 
        taxes.COUNTYFIPS[i] = add_char(taxes.COUNTYFIPS[i],0,0)
    else:
        taxes.COUNTYFIPS[i] = taxes.COUNTYFIPS[i]
        
taxes["FIPS"] = taxes["STATEFIPS"] + taxes["COUNTYFIPS"]

taxes = taxes[["STATE", "COUNTYNAME",
            "N1", "A00100", "A02650", "A18425",
             "A18450", "A18500", "A18800", "A18300", "A10600", "FIPS"]]
taxes = taxes.rename(columns={"COUNTYNAME":"COUNTY","N1":"Num_Returns",
                             "A00100":"adj_gross_income", "A02650":"total_income",
                              "A18425": "st_local_income_tax","A18450":"st_local_gen_sales_tax", 
                              "A18500":"realestate_tax", "A18800":"personal_prop_tax", 
                              "A18300":"total_taxes_paid", "A10600":"total_tax_payments_amt"})
taxes["YEAR"] = 2021

# %%
taxes
# Out:
#      STATE             COUNTY  Num_Returns  adj_gross_income  total_income  \
# 0       AL            Alabama    2162210.0       154268214.0  1.555913e+08
# 1       AL     Autauga County      25720.0         1688218.0  1.700226e+06
# 2       AL     Baldwin County     111140.0         9360157.0  9.458767e+06
# 3       AL     Barbour County       9740.0          448442.0  4.521740e+05
# 4       AL        Bibb County       8230.0          533851.0  5.365300e+05
# ...    ...                ...          ...               ...           ...
# 3189    WY  Sweetwater County      19530.0         1427418.0  1.434327e+06
# 3190    WY       Teton County      14860.0         9561613.0  9.622477e+06
# 3191    WY       Uinta County       9350.0          673690.0  6.776150e+05
# 3192    WY    Washakie County       3790.0          263135.0  2.651970e+05
# 3193    WY      Weston County       3190.0          215820.0  2.177600e+05
#
#       st_local_income_tax  st_local_gen_sales_tax  realestate_tax  \
# 0               1357554.0                 45611.0        334941.0
# 1                  8910.0                   688.0          1804.0
# 2                 80172.0                  3321.0         19336.0
# 3                  1776.0                   127.0           518.0
# 4                  2441.0                   115.0           257.0
# ...                   ...                     ...             ...
# 3189                385.0                  1007.0          2176.0
# 3190             131000.0                  6024.0         50928.0
# 3191                454.0                   500.0          1019.0
# 3192                  0.0                    94.0           226.0
# 3193                  0.0                   121.0           266.0
#
#       personal_prop_tax  total_taxes_paid  total_tax_payments_amt   FIPS  YEAR
# 0               46903.0          974173.0              24008761.0  01000  2021
# 1                 303.0            8741.0                228794.0  01001  2021
# 2                2038.0           58098.0               1359923.0  01003  2021
# 3                  87.0            1903.0                 66115.0  01005  2021
# 4                 170.0            1770.0                 87801.0  01007  2021
# ...                 ...               ...                     ...    ...   ...
# 3189              725.0            3779.0                205811.0  56037  2021
# 3190             1461.0           21604.0               2360933.0  56039  2021
# 3191              318.0            2116.0                 96917.0  56041  2021
# 3192               48.0             451.0                 30352.0  56043  2021
# 3193               48.0             481.0                 29691.0  56045  2021
#
# [3194 rows x 13 columns]

# %%
steal=taxes.FIPS
steal
# Out:
# 0       01000
# 1       01001
# 2       01003
# 3       01005
# 4       01007
#         ...
# 3189    56037
# 3190    56039
# 3191    56041
# 3192    56043
# 3193    56045
# Name: FIPS, Length: 3194, dtype: string

# %%
taxes.dtypes
# Out:
# STATE                      object
# COUNTY                     object
# Num_Returns               float64
# adj_gross_income          float64
# total_income              float64
# st_local_income_tax       float64
# st_local_gen_sales_tax    float64
# realestate_tax            float64
# personal_prop_tax         float64
# total_taxes_paid          float64
# total_tax_payments_amt    float64
# FIPS                       string
# YEAR                        int64
# dtype: object

# %%
taxes.to_csv("taxes_capstone.csv")

# %%
hosp = pd.read_csv("Hospital_General_Information.csv")

# %%
hosp = hosp[["City/Town", "State", "ZIP Code", "County/Parish", "Emergency Services"]]
hosp = hosp.rename(columns={"City/Town":"CITY", "State":"STATE", "County/Parish":"COUNTY"})

# %%
hosp
# Out:
#             CITY STATE  ZIP Code      COUNTY Emergency Services
# 0         DOTHAN    AL     36301     HOUSTON                Yes
# 1           BOAZ    AL     35957    MARSHALL                Yes
# 2       FLORENCE    AL     35630  LAUDERDALE                Yes
# 3            OPP    AL     36467   COVINGTON                Yes
# 4        LUVERNE    AL     36049    CRENSHAW                Yes
# ...          ...   ...       ...         ...                ...
# 5420  MIDLOTHIAN    TX     76065       ELLIS                Yes
# 5421   MANSFIELD    TX     76063     TARRANT                Yes
# 5422      HUMBLE    TX     77338      HARRIS                 No
# 5423  SUGAR LAND    TX     77479   FORT BEND                Yes
# 5424      SACHSE    TX     75048      DALLAS                Yes
#
# [5425 rows x 5 columns]

# %%
for i in range(len(hosp.COUNTY)): 
    string_list = list(hosp.COUNTY[i])
    string_list = string_list.insert(len(hosp.COUNTY[i], " County")
    new_string = "".join(string_list)
    hosp.COUNTY[i] = string_list
    
hosp
# Out:
#   File "/var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/51528039.py", line 4
#     new_string = "".join(string_list)
#     ^
# SyntaxError: invalid syntax

# %%
for i in range(len(hosp.COUNTY)):
    st_list = list(hosp.COUNTY[i])
    st_list.insert(len(hosp.COUNTY[i]), " County")
    hosp.COUNTY[i] = "".join(st_list)
# Out:
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/428418842.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hosp.COUNTY[i] = "".join(st_list)

# %%
hosp
# Out:
#             CITY STATE  ZIP Code             COUNTY Emergency Services
# 0         DOTHAN    AL     36301     HOUSTON County                Yes
# 1           BOAZ    AL     35957    MARSHALL County                Yes
# 2       FLORENCE    AL     35630  LAUDERDALE County                Yes
# 3            OPP    AL     36467   COVINGTON County                Yes
# 4        LUVERNE    AL     36049    CRENSHAW County                Yes
# ...          ...   ...       ...                ...                ...
# 5420  MIDLOTHIAN    TX     76065       ELLIS County                Yes
# 5421   MANSFIELD    TX     76063     TARRANT County                Yes
# 5422      HUMBLE    TX     77338      HARRIS County                 No
# 5423  SUGAR LAND    TX     77479   FORT BEND County                Yes
# 5424      SACHSE    TX     75048      DALLAS County                Yes
#
# [5425 rows x 5 columns]

# %%
hosp.to_csv("hospital_capstone.csv")

# %%
a = list(hosp.COUNTY[0])
a.insert(len(a), " County")
b = "".join(a)
b
# Out:
# 'HOUSTON County'

# %% [markdown]
# ### nextt one

# %%
lg101 = pd.read_csv("local_gov101.csv")
lg101= lg101[["area_fips", "own_code", "industry_code", "agglvl_code", "year",
              "annual_avg_estabs", "annual_avg_emplvl", "total_annual_wages", 
              "annual_avg_wkly_wage", "avg_annual_pay"]]
lg102 = pd.read_csv("local_gov102.csv")
lg102 = lg102[["area_fips", "own_code", "industry_code", "agglvl_code", "year",
              "annual_avg_estabs", "annual_avg_emplvl", "total_annual_wages", 
              "annual_avg_wkly_wage", "avg_annual_pay"]]

        
        
for i in range(len(lg101.area_fips)):
    string_list = list(lg101.area_fips[i])
    if string_list[-3:] == ["0","0","0"]: 
        lg101 = lg101.drop([i])
    elif string_list[0]== "C":
        lg101 = lg101.drop([i])
    else: 
        lg101 = lg101
     # Join the list back into a string 
    lg101.area_fips[i] = "".join(string_list)   
for i in range(len(lg102.area_fips)):
    string_list = list(lg102.area_fips[i])
    if string_list[-3:] == ["0","0","0"] : 
        lg102 = lg102.drop([i])
    elif string_list[0]== "C":
        lg102 = lg102.drop([i])
        
    else: 
        lg102 = lg102
     # Join the list back into a string 
    lg102.area_fips[i] = "".join(string_list)
# Out:
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg101.area_fips[i] = "".join(string_list)
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/4126671241.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lg102.area_fips[i] = "".join(string_list)

# %%
lg102.reset_index()
# Out:
#        index area_fips  own_code  industry_code  agglvl_code  year  \
# 0          4     01001         1            102           72  2022
# 1          5     01001         2            102           72  2022
# 2          6     01001         3            102           72  2022
# 3          7     01001         5            102           72  2022
# 4          8     01003         1            102           72  2022
# ...      ...       ...       ...            ...          ...   ...
# 12991  13202     78020         2            102           72  2022
# 12992  13203     78020         5            102           72  2022
# 12993  13204     78030         1            102           72  2022
# 12994  13205     78030         2            102           72  2022
# 12995  13206     78030         5            102           72  2022
#
#        annual_avg_estabs  annual_avg_emplvl  total_annual_wages  \
# 0                     10                 87             5562233
# 1                     18                579            34704754
# 2                     32               1852            87117708
# 3                    799               6780           264625510
# 4                     35                378            25642003
# ...                  ...                ...                 ...
# 12991                  1                  7              218567
# 12992                286               1663            74286768
# 12993                 29                579            56400267
# 12994                 44               5338           346260446
# 12995               1652              11780           504744899
#
#        annual_avg_wkly_wage  avg_annual_pay
# 0                      1237           64303
# 1                      1152           59905
# 2                       905           47053
# 3                       751           39030
# 4                      1305           67881
# ...                     ...             ...
# 12991                   608           31600
# 12992                   859           44664
# 12993                  1874           97452
# 12994                  1247           64866
# 12995                   824           42849
#
# [12996 rows x 11 columns]

# %%
while i < lg102.area_fips:
    np.where( lg102.area_fips == lg102.area_fips[i])

# %%
lg102.reset_index(inplace=True)
lg102["area_fips"]
# Out:
# 0        01001
# 1        01001
# 2        01001
# 3        01001
# 4        01003
#          ...
# 12991    78020
# 12992    78020
# 12993    78030
# 12994    78030
# 12995    78030
# Name: area_fips, Length: 12996, dtype: object

# %%
lg102["area_fips"][0]
# Out:
# '01001'

# %%
lg102
# Out:
#        index area_fips  own_code  industry_code  agglvl_code  year  \
# 0          4     01001         1            102           72  2022
# 1          5     01001         2            102           72  2022
# 2          6     01001         3            102           72  2022
# 3          7     01001         5            102           72  2022
# 4          8     01003         1            102           72  2022
# ...      ...       ...       ...            ...          ...   ...
# 12991  13202     78020         2            102           72  2022
# 12992  13203     78020         5            102           72  2022
# 12993  13204     78030         1            102           72  2022
# 12994  13205     78030         2            102           72  2022
# 12995  13206     78030         5            102           72  2022
#
#        annual_avg_estabs  annual_avg_emplvl  total_annual_wages  \
# 0                     10                 87             5562233
# 1                     18                579            34704754
# 2                     32               1852            87117708
# 3                    799               6780           264625510
# 4                     35                378            25642003
# ...                  ...                ...                 ...
# 12991                  1                  7              218567
# 12992                286               1663            74286768
# 12993                 29                579            56400267
# 12994                 44               5338           346260446
# 12995               1652              11780           504744899
#
#        annual_avg_wkly_wage  avg_annual_pay
# 0                      1237           64303
# 1                      1152           59905
# 2                       905           47053
# 3                       751           39030
# 4                      1305           67881
# ...                     ...             ...
# 12991                   608           31600
# 12992                   859           44664
# 12993                  1874           97452
# 12994                  1247           64866
# 12995                   824           42849
#
# [12996 rows x 11 columns]

# %%
lg102.groupby("area_fips")["index","own_code"].mean()
# Out:
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/2171179826.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   lg102.groupby("area_fips")["index","own_code"].mean()
#              index  own_code
# area_fips
# 01001          5.5  2.750000
# 01003          9.5  2.750000
# 01005         13.5  2.750000
# 01007         17.5  2.750000
# 01009         21.5  2.750000
# ...            ...       ...
# 72153      13189.5  2.750000
# 72999      13193.0  2.666667
# 78010      13199.0  2.666667
# 78020      13202.0  2.666667
# 78030      13205.0  2.666667
#
# [3274 rows x 2 columns]

# %%
for i in range(len(steal)):

# %%
lg102[lg102==lg102.area_fips[0]]
# Out:
#        index area_fips  own_code  industry_code  agglvl_code  year  \
# 0        NaN     01001       NaN            NaN          NaN   NaN
# 1        NaN     01001       NaN            NaN          NaN   NaN
# 2        NaN     01001       NaN            NaN          NaN   NaN
# 3        NaN     01001       NaN            NaN          NaN   NaN
# 4        NaN       NaN       NaN            NaN          NaN   NaN
# ...      ...       ...       ...            ...          ...   ...
# 12991    NaN       NaN       NaN            NaN          NaN   NaN
# 12992    NaN       NaN       NaN            NaN          NaN   NaN
# 12993    NaN       NaN       NaN            NaN          NaN   NaN
# 12994    NaN       NaN       NaN            NaN          NaN   NaN
# 12995    NaN       NaN       NaN            NaN          NaN   NaN
#
#        annual_avg_estabs  annual_avg_emplvl  total_annual_wages  \
# 0                    NaN                NaN                 NaN
# 1                    NaN                NaN                 NaN
# 2                    NaN                NaN                 NaN
# 3                    NaN                NaN                 NaN
# 4                    NaN                NaN                 NaN
# ...                  ...                ...                 ...
# 12991                NaN                NaN                 NaN
# 12992                NaN                NaN                 NaN
# 12993                NaN                NaN                 NaN
# 12994                NaN                NaN                 NaN
# 12995                NaN                NaN                 NaN
#
#        annual_avg_wkly_wage  avg_annual_pay
# 0                       NaN             NaN
# 1                       NaN             NaN
# 2                       NaN             NaN
# 3                       NaN             NaN
# 4                       NaN             NaN
# ...                     ...             ...
# 12991                   NaN             NaN
# 12992                   NaN             NaN
# 12993                   NaN             NaN
# 12994                   NaN             NaN
# 12995                   NaN             NaN
#
# [12996 rows x 11 columns]

# %%
lg102.index[lg102[lg102==lg102.area_fips[0]]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/365516481.py in <module>
# ----> 1 lg102.index[lg102[lg102==lg102.area_fips[0]]]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/range.py in __getitem__(self, key)
#     940             )
#     941         # fall back to Int64Index
# --> 942         return super().__getitem__(key)
#     943
#     944     def _getitem_slice(self: RangeIndex, slobj: slice) -> RangeIndex:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    5067             key = np.asarray(key, dtype=bool)
#    5068
# -> 5069         result = getitem(key)
#    5070         # Because we ruled out integer above, we always get an arraylike here
#    5071         if result.ndim > 1:
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
lg102.index[lg102[lg102==lg102.area_fips[1]]].any(axis=1).tolist()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/725139221.py in <module>
# ----> 1 lg102.index[lg102[lg102==lg102.area_fips[1]]].any(axis=1).tolist()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/range.py in __getitem__(self, key)
#     940             )
#     941         # fall back to Int64Index
# --> 942         return super().__getitem__(key)
#     943
#     944     def _getitem_slice(self: RangeIndex, slobj: slice) -> RangeIndex:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    5067             key = np.asarray(key, dtype=bool)
#    5068
# -> 5069         result = getitem(key)
#    5070         # Because we ruled out integer above, we always get an arraylike here
#    5071         if result.ndim > 1:
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
lg102.index[lg102[lg102 == lg102.area_fips[0]
df.index[df[df==1].any(axis=1)].tolist()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/2057088986.py in <module>
# ----> 1 lg102.area_fips == lg102.area_fips[0]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in __getitem__(self, key)
#     956
#     957         elif key_is_scalar:
# --> 958             return self._get_value(key)
#     959
#     960         if is_hashable(key):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1067
#    1068         # Similar to Index.get_value, but we do not fall back to positional
# -> 1069         loc = self.index.get_loc(label)
#    1070         return self.index._get_values_for_loc(self, loc, label)
#    1071
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 0

# %%
np.where(lg102.area_fips == lg102.area_fips[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/1374332950.py in <module>
# ----> 1 np.where(lg102.area_fips == lg102.area_fips[0])
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in __getitem__(self, key)
#     956
#     957         elif key_is_scalar:
# --> 958             return self._get_value(key)
#     959
#     960         if is_hashable(key):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1067
#    1068         # Similar to Index.get_value, but we do not fall back to positional
# -> 1069         loc = self.index.get_loc(label)
#    1070         return self.index._get_values_for_loc(self, loc, label)
#    1071
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 0

# %%
lg101.shape
# Out:
# (6514, 10)

# %%
lg102.shape
# Out:
# (12996, 10)

# %%
len(lg101.area_fips)
# Out:
# 6514

# %%
la = lg102.set_index("area_fips")
lo = lg101.set_index("area_fips")
fr = lo.join(la, lsuffix="haha", how= "outer")
fr
# Out:
#            own_codehaha  industry_codehaha  agglvl_codehaha  yearhaha  \
# area_fips
# 01001                 5                101               72      2022
# 01001                 5                101               72      2022
# 01001                 5                101               72      2022
# 01001                 5                101               72      2022
# 01003                 5                101               72      2022
# ...                 ...                ...              ...       ...
# 78020                 5                101               72      2022
# 78020                 5                101               72      2022
# 78030                 5                101               72      2022
# 78030                 5                101               72      2022
# 78030                 5                101               72      2022
#
#            annual_avg_estabshaha  annual_avg_emplvlhaha  \
# area_fips
# 01001                        161                   2238
# 01001                        161                   2238
# 01001                        161                   2238
# 01001                        161                   2238
# 01003                       1192                  10033
# ...                          ...                    ...
# 78020                         36                    157
# 78020                         36                    157
# 78030                        187                    871
# 78030                        187                    871
# 78030                        187                    871
#
#            total_annual_wageshaha  annual_avg_wkly_wagehaha  \
# area_fips
# 01001                   145272025                      1248
# 01001                   145272025                      1248
# 01001                   145272025                      1248
# 01001                   145272025                      1248
# 01003                   603282127                      1156
# ...                           ...                       ...
# 78020                     8476362                      1038
# 78020                     8476362                      1038
# 78030                    54206980                      1196
# 78030                    54206980                      1196
# 78030                    54206980                      1196
#
#            avg_annual_payhaha  own_code  industry_code  agglvl_code  year  \
# area_fips
# 01001                   64916         1            102           72  2022
# 01001                   64916         2            102           72  2022
# 01001                   64916         3            102           72  2022
# 01001                   64916         5            102           72  2022
# 01003                   60132         1            102           72  2022
# ...                       ...       ...            ...          ...   ...
# 78020                   53990         2            102           72  2022
# 78020                   53990         5            102           72  2022
# 78030                   62206         1            102           72  2022
# 78030                   62206         2            102           72  2022
# 78030                   62206         5            102           72  2022
#
#            annual_avg_estabs  annual_avg_emplvl  total_annual_wages  \
# area_fips
# 01001                     10                 87             5562233
# 01001                     18                579            34704754
# 01001                     32               1852            87117708
# 01001                    799               6780           264625510
# 01003                     35                378            25642003
# ...                      ...                ...                 ...
# 78020                      1                  7              218567
# 78020                    286               1663            74286768
# 78030                     29                579            56400267
# 78030                     44               5338           346260446
# 78030                   1652              11780           504744899
#
#            annual_avg_wkly_wage  avg_annual_pay
# area_fips
# 01001                      1237           64303
# 01001                      1152           59905
# 01001                       905           47053
# 01001                       751           39030
# 01003                      1305           67881
# ...                         ...             ...
# 78020                       608           31600
# 78020                       859           44664
# 78030                      1874           97452
# 78030                      1247           64866
# 78030                       824           42849
#
# [24335 rows x 18 columns]

# %%
for i in range(len(steal)):
# Out:
# 3194

# %%
lg101.area_fips
# Out:
# 2       01001
# 3       01003
# 4       01005
# 5       01007
# 6       01009
#         ...
# 6683    C4942
# 6684    C4962
# 6685    C4966
# 6686    C4970
# 6687    C4974
# Name: area_fips, Length: 6514, dtype: object

# %%
lg101.area_fips[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/1904891871.py in <module>
# ----> 1 lg101.area_fips[0]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in __getitem__(self, key)
#     956
#     957         elif key_is_scalar:
# --> 958             return self._get_value(key)
#     959
#     960         if is_hashable(key):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1067
#    1068         # Similar to Index.get_value, but we do not fall back to positional
# -> 1069         loc = self.index.get_loc(label)
#    1070         return self.index._get_values_for_loc(self, loc, label)
#    1071
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 0

# %%
string_list = list(lg101.area_fips[0])
string_list
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/2473542641.py in <module>
# ----> 1 string_list = list(lg101.area_fips[0])
#       2 string_list
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in __getitem__(self, key)
#     956
#     957         elif key_is_scalar:
# --> 958             return self._get_value(key)
#     959
#     960         if is_hashable(key):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1067
#    1068         # Similar to Index.get_value, but we do not fall back to positional
# -> 1069         loc = self.index.get_loc(label)
#    1070         return self.index._get_values_for_loc(self, loc, label)
#    1071
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 0

# %%
for i in range(0,len(lg101.area_fips)):
    string_list = list(lg101.area_fips[i])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/3667376015.py in <module>
#       1 for i in range(0,len(lg101.area_fips)):
# ----> 2     string_list = list(lg101.area_fips[i])
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in __getitem__(self, key)
#     956
#     957         elif key_is_scalar:
# --> 958             return self._get_value(key)
#     959
#     960         if is_hashable(key):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1067
#    1068         # Similar to Index.get_value, but we do not fall back to positional
# -> 1069         loc = self.index.get_loc(label)
#    1070         return self.index._get_values_for_loc(self, loc, label)
#    1071
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 0

# %%
for i in range(0,len(lg101.area_fips)):
    string_list = list(lg101.area_fips[i])
    if string_list[0] == "C": 
        lg101 = lg101.drop([i])
        
    else: 
        lg101 = lg101
     # Join the list back into a string 
    lg101.area_fips[i] = "".join(string_list)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_52413/1889835298.py in <module>
#       1 for i in range(1,len(lg101.area_fips)):
# ----> 2     string_list = list(lg101.area_fips[i])
#       3     if string_list[0] == "C":
#       4         lg101 = lg101.drop([i])
#       5
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in __getitem__(self, key)
#     956
#     957         elif key_is_scalar:
# --> 958             return self._get_value(key)
#     959
#     960         if is_hashable(key):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1067
#    1068         # Similar to Index.get_value, but we do not fall back to positional
# -> 1069         loc = self.index.get_loc(label)
#    1070         return self.index._get_values_for_loc(self, loc, label)
#    1071
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 1

# %%
lg101.area_fips.astype("int64")

# %%
combo = lg102.join(lg101, on="area_fips",how="outer", lsuffix="102")
combo

# %%
crime = pd.read_csv("Table_6_Crime_in_the_United_States_by_Metropolitan_Statistical_Area_2019.csv", encoding='ISO-8859-1')

# %%
crime
# Out:
#      Metropolitan Statistical Area  \
# 0               Abilene, TX M.S.A.
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ...                            ...
# 1928                           NaN
# 1929     Yauco, Puerto Rico M.S.A.
# 1930                           NaN
# 1931                           NaN
# 1932                           NaN
#
#                               Counties/principal cities Population  \
# 0                                                   NaN    171,125
# 1         Includes Callahan, Jones, and Taylor Counties        NaN
# 2                                       City of Abilene    123,665
# 3                         Total area actually reporting     100.0%
# 4                          Rate per 100,000 inhabitants        NaN
# ...                                                 ...        ...
# 1928                       Rate per 100,000 inhabitants        NaN
# 1929                                                NaN     85,830
# 1930  Includes Guanica, Guayanilla, Penuelas, and Ya...     85,830
# 1931                      Total area actually reporting     100.0%
# 1932                       Rate per 100,000 inhabitants        NaN
#
#      Violent\ncrime Murder and\nnonnegligent\nmanslaughter Rape1 Robbery  \
# 0                                                      NaN   NaN     NaN
# 1               NaN                                    NaN   NaN     NaN
# 2              458                                      6    87      68
# 3              543                                      6   105      72
# 4             317.3                                    3.5  61.4    42.1
# ...             ...                                    ...   ...     ...
# 1928          227.3                                   23.6   6.8    86.7
# 1929            NaN                                    NaN   NaN     NaN
# 1930            NaN                                    NaN   NaN     NaN
# 1931           148                                     10    11      19
# 1932          172.4                                   11.7  12.8    22.1
#
#      Aggravated\nassault Property\ncrime Burglary Larceny-\ntheft  \
# 0                    NaN                      NaN             NaN
# 1                    NaN             NaN      NaN             NaN
# 2                   297           3,112      576           2,330
# 3                   360           3,603      765           2,596
# 4                  210.4         2,105.5    447.0         1,517.0
# ...                  ...             ...      ...             ...
# 1928               110.2           845.0    143.1           542.0
# 1929                 NaN             NaN      NaN             NaN
# 1930                 NaN             NaN      NaN             NaN
# 1931                108             267       66             184
# 1932               125.8           311.1     76.9           214.4
#
#      Motor\nvehicle\ntheft
# 0                      NaN
# 1                      NaN
# 2                     206
# 3                     242
# 4                    141.4
# ...                    ...
# 1928                 159.9
# 1929                   NaN
# 1930                   NaN
# 1931                   17
# 1932                  19.8
#
# [1933 rows x 12 columns]
