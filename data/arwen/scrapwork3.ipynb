# %%
import pandas as pd
import numpy as np

# %%
lg101 = pd.read_csv("local_gov101.csv")
lg101= lg101[["area_fips", "own_code", "industry_code", "agglvl_code", "year",
              "annual_avg_estabs", "annual_avg_emplvl", "total_annual_wages", 
              "annual_avg_wkly_wage", "avg_annual_pay"]]
lg102 = pd.read_csv("local_gov102.csv")
lg102 = lg102[["area_fips", "own_code", "industry_code", "agglvl_code", "year",
              "annual_avg_estabs", "annual_avg_emplvl", "total_annual_wages", 
              "annual_avg_wkly_wage", "avg_annual_pay"]]
lg1011 = pd.read_csv("local_gov1011.csv")
lg1011= lg1011[["area_fips", "own_code", "industry_code", "agglvl_code", "year",
              "annual_avg_estabs", "annual_avg_emplvl", "total_annual_wages", 
              "annual_avg_wkly_wage", "avg_annual_pay"]]
lg1012 = pd.read_csv("local_gov1012.csv")
lg1012= lg1012[["area_fips", "own_code", "industry_code", "agglvl_code", "year",
              "annual_avg_estabs", "annual_avg_emplvl", "total_annual_wages", 
              "annual_avg_wkly_wage", "avg_annual_pay"]]
lg1013 = pd.read_csv("local_gov1013.csv")
lg1013= lg1013[["area_fips", "own_code", "industry_code", "agglvl_code", "year",
              "annual_avg_estabs", "annual_avg_emplvl", "total_annual_wages", 
              "annual_avg_wkly_wage", "avg_annual_pay"]]
lg1021 = pd.read_csv("local_gov1021.csv")
lg1021= lg1021[["area_fips", "own_code", "industry_code", "agglvl_code", "year",
              "annual_avg_estabs", "annual_avg_emplvl", "total_annual_wages", 
              "annual_avg_wkly_wage", "avg_annual_pay"]]
lg1022 = pd.read_csv("local_gov1022.csv")
lg1022= lg1022[["area_fips", "own_code", "industry_code", "agglvl_code", "year",
              "annual_avg_estabs", "annual_avg_emplvl", "total_annual_wages", 
              "annual_avg_wkly_wage", "avg_annual_pay"]]
lg1023 = pd.read_csv("local_gov1023.csv")
lg1023= lg1023[["area_fips", "own_code", "industry_code", "agglvl_code", "year",
              "annual_avg_estabs", "annual_avg_emplvl", "total_annual_wages", 
              "annual_avg_wkly_wage", "avg_annual_pay"]]
lg1024 = pd.read_csv("local_gov1024.csv")
lg1024= lg1024[["area_fips", "own_code", "industry_code", "agglvl_code", "year",
              "annual_avg_estabs", "annual_avg_emplvl", "total_annual_wages", 
              "annual_avg_wkly_wage", "avg_annual_pay"]]
lg1025 = pd.read_csv("local_gov1025.csv")
lg1025= lg1025[["area_fips", "own_code", "industry_code", "agglvl_code", "year",
              "annual_avg_estabs", "annual_avg_emplvl", "total_annual_wages", 
              "annual_avg_wkly_wage", "avg_annual_pay"]]
lg1026 = pd.read_csv("local_gov1026.csv")
lg1026= lg1026[["area_fips", "own_code", "industry_code", "agglvl_code", "year",
              "annual_avg_estabs", "annual_avg_emplvl", "total_annual_wages", 
              "annual_avg_wkly_wage", "avg_annual_pay"]]
lg1027 = pd.read_csv("local_gov1027.csv")
lg1027= lg1027[["area_fips", "own_code", "industry_code", "agglvl_code", "year",
              "annual_avg_estabs", "annual_avg_emplvl", "total_annual_wages", 
              "annual_avg_wkly_wage", "avg_annual_pay"]]
lg1028 = pd.read_csv("local_gov1028.csv")
lg1028= lg1028[["area_fips", "own_code", "industry_code", "agglvl_code", "year",
              "annual_avg_estabs", "annual_avg_emplvl", "total_annual_wages", 
              "annual_avg_wkly_wage", "avg_annual_pay"]]
lg1029 = pd.read_csv("local_gov1029.csv")
lg1029= lg1029[["area_fips", "own_code", "industry_code", "agglvl_code", "year",
              "annual_avg_estabs", "annual_avg_emplvl", "total_annual_wages", 
              "annual_avg_wkly_wage", "avg_annual_pay"]]

# %%
lg101a = lg101.groupby("area_fips")["annual_avg_estabs", "annual_avg_emplvl",
                               "total_annual_wages"].sum()
lg101b = lg101.groupby("area_fips")["annual_avg_wkly_wage", "avg_annual_pay"].mean()
# Out:
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_61737/935535032.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   lg101a = lg101.groupby("area_fips")["annual_avg_estabs", "annual_avg_emplvl",
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_61737/935535032.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   lg101b = lg101.groupby("area_fips")["annual_avg_wkly_wage", "avg_annual_pay"].mean()

# %%
lg102a = lg102.groupby("area_fips")["annual_avg_estabs", "annual_avg_emplvl",
                               "total_annual_wages"].sum()
lg102b = lg102.groupby("area_fips")["annual_avg_wkly_wage", "avg_annual_pay"].mean()
# Out:
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_61737/4131448539.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   lg102a = lg102.groupby("area_fips")["annual_avg_estabs", "annual_avg_emplvl",
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_61737/4131448539.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   lg102b = lg102.groupby("area_fips")["annual_avg_wkly_wage", "avg_annual_pay"].mean()

# %%
lg101c = lg101a.join(lg101b)
lg102c = lg102a.join(lg102b)

# %%
lg1011a = lg1011.groupby("area_fips")["annual_avg_estabs", "annual_avg_emplvl",
                               "total_annual_wages"].sum()
lg1011b = lg1011.groupby("area_fips")["annual_avg_wkly_wage", "avg_annual_pay"].mean()
lg1011c = lg1011a.join(lg1011b)

lg1012a = lg1012.groupby("area_fips")["annual_avg_estabs", "annual_avg_emplvl",
                               "total_annual_wages"].sum()
lg1012b = lg1012.groupby("area_fips")["annual_avg_wkly_wage", "avg_annual_pay"].mean()
lg1012c = lg1012a.join(lg1012b)

lg1013a = lg1013.groupby("area_fips")["annual_avg_estabs", "annual_avg_emplvl",
                               "total_annual_wages"].sum()
lg1013b = lg1013.groupby("area_fips")["annual_avg_wkly_wage", "avg_annual_pay"].mean()
lg1013c = lg1013a.join(lg1013b)

lg1021a = lg1021.groupby("area_fips")["annual_avg_estabs", "annual_avg_emplvl",
                               "total_annual_wages"].sum()
lg1021b = lg1021.groupby("area_fips")["annual_avg_wkly_wage", "avg_annual_pay"].mean()
lg1021c = lg1021a.join(lg1021b)

lg1022a = lg1022.groupby("area_fips")["annual_avg_estabs", "annual_avg_emplvl",
                               "total_annual_wages"].sum()
lg1022b = lg1022.groupby("area_fips")["annual_avg_wkly_wage", "avg_annual_pay"].mean()
lg1022c = lg1022a.join(lg1022b)

lg1023a = lg1023.groupby("area_fips")["annual_avg_estabs", "annual_avg_emplvl",
                               "total_annual_wages"].sum()
lg1023b = lg1023.groupby("area_fips")["annual_avg_wkly_wage", "avg_annual_pay"].mean()
lg1023c = lg1023a.join(lg1023b)

lg1024a = lg1024.groupby("area_fips")["annual_avg_estabs", "annual_avg_emplvl",
                               "total_annual_wages"].sum()
lg1024b = lg1024.groupby("area_fips")["annual_avg_wkly_wage", "avg_annual_pay"].mean()
lg1024c = lg1024a.join(lg1024b)

lg1025a = lg1025.groupby("area_fips")["annual_avg_estabs", "annual_avg_emplvl",
                               "total_annual_wages"].sum()
lg1025b = lg1025.groupby("area_fips")["annual_avg_wkly_wage", "avg_annual_pay"].mean()
lg1025c = lg1025a.join(lg1025b)

lg1026a = lg1026.groupby("area_fips")["annual_avg_estabs", "annual_avg_emplvl",
                               "total_annual_wages"].sum()
lg1026b = lg1026.groupby("area_fips")["annual_avg_wkly_wage", "avg_annual_pay"].mean()
lg1026c = lg1026a.join(lg1026b)

lg1027a = lg1027.groupby("area_fips")["annual_avg_estabs", "annual_avg_emplvl",
                               "total_annual_wages"].sum()
lg1027b = lg1027.groupby("area_fips")["annual_avg_wkly_wage", "avg_annual_pay"].mean()
lg1027c = lg1027a.join(lg1027b)

lg1028a = lg1028.groupby("area_fips")["annual_avg_estabs", "annual_avg_emplvl",
                               "total_annual_wages"].sum()
lg1028b = lg1028.groupby("area_fips")["annual_avg_wkly_wage", "avg_annual_pay"].mean()
lg1028c = lg1028a.join(lg1028b)

lg1029a = lg1029.groupby("area_fips")["annual_avg_estabs", "annual_avg_emplvl",
                               "total_annual_wages"].sum()
lg1029b = lg1029.groupby("area_fips")["annual_avg_wkly_wage", "avg_annual_pay"].mean()
lg1029c = lg1029a.join(lg1021b)
# Out:
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_61737/378605217.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   lg1011a = lg1011.groupby("area_fips")["annual_avg_estabs", "annual_avg_emplvl",
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_61737/378605217.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   lg1011b = lg1011.groupby("area_fips")["annual_avg_wkly_wage", "avg_annual_pay"].mean()
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_61737/378605217.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   lg1012a = lg1012.groupby("area_fips")["annual_avg_estabs", "annual_avg_emplvl",
# ...

# %%
combo = lg102c.join(lg101c, lsuffix="_service", how="outer")
combo = lg1011c.join(combo, lsuffix="_mining", how="outer")
combo = lg1012c.join(combo, lsuffix="_construction", how="outer")
combo = lg1013c.join(combo, lsuffix="_manufacturing", how="outer")
combo = lg1021c.join(combo, lsuffix="_trade_transport_util", how="outer")
combo = lg1022c.join(combo, lsuffix="_information", how="outer")
combo = lg1023c.join(combo, lsuffix="_finance", how="outer")
combo = lg1024c.join(combo, lsuffix="_business", how="outer")
combo = lg1025c.join(combo, lsuffix="_education_health", how="outer")
combo = lg1026c.join(combo, lsuffix="_hospitality_leasure", how="outer")
combo = lg1027c.join(combo, lsuffix="_other", how="outer")
combo = lg1028c.join(combo, lsuffix="_publicadmin", how="outer")
combo = lg1029c.join(combo, lsuffix="_unclassified", how="outer")

# %%
combo
# Out:
#            annual_avg_estabs_unclassified  annual_avg_emplvl_unclassified  \
# area_fips
# 01000                                14.0                             2.0
# 01001                                 NaN                             NaN
# 01003                                 NaN                             NaN
# 01005                                 NaN                             NaN
# 01007                                 NaN                             NaN
# ...                                   ...                             ...
# C4962                                 NaN                             NaN
# C4966                                22.0                            45.0
# C4970                                 3.0                             0.0
# C4974                               109.0                           191.0
# US000                            346364.0                        295426.0
#
# ...

# %%
combo = combo.rename(columns={"area_fips":"FIPS", 
                      "avg_annual_pay":"avg_annual_pay_unclassifed_goodsproduction",
                     "annual_avg_wkly_wage":"annual_avg_wkly_wage_goodsproduction",
                     "total_annual_wages":"total_annual_wages_goodsproduction",
                      "annual_avg_emplvl":	"annual_avg_emplvl_goodsproduction",
                    "annual_avg_estab":"annual_avg_estab_goodsproduction"})

# %%
combo.to_csv("employment_capstone.csv")

# %%
employment = pd.read_csv("Cleaned Data/employment_capstone.csv")
taxes = pd.read_csv("Cleaned Data/taxes_capstone.csv")

# %%
employment["YEAR_employment"] = 2022

# %%
employment = employment.rename(columns={"area_fips":"FIPS"})
employment
# Out:
#        FIPS  annual_avg_estabs_unclassified  annual_avg_emplvl_unclassified  \
# 0     01000                            14.0                             2.0
# 1     01001                             NaN                             NaN
# 2     01003                             NaN                             NaN
# 3     01005                             NaN                             NaN
# 4     01007                             NaN                             NaN
# ...     ...                             ...                             ...
# 3711  C4962                             NaN                             NaN
# 3712  C4966                            22.0                            45.0
# 3713  C4970                             3.0                             0.0
# 3714  C4974                           109.0                           191.0
# 3715  US000                        346364.0                        295426.0
#
# ...

# %%
employment.dtypes
# Out:
# FIPS                                           object
# annual_avg_estabs_unclassified                float64
# annual_avg_emplvl_unclassified                float64
# total_annual_wages_unclassified               float64
# annual_avg_wkly_wage_unclassified             float64
#                                                ...
# annual_avg_emplvl_goodsproduction               int64
# total_annual_wages_goodsproduction              int64
# annual_avg_wkly_wage_goodsproduction          float64
# avg_annual_pay_unclassifed_goodsproduction    float64
# YEAR_employment                                 int64
# Length: 72, dtype: object

# %%
taxes.dtypes
# Out:
# Unnamed: 0                  int64
# STATE                      object
# COUNTY                     object
# Num_Returns               float64
# adj_gross_income          float64
# total_income              float64
# st_local_income_tax       float64
# st_local_gen_sales_tax    float64
# realestate_tax            float64
# personal_prop_tax         float64
# total_taxes_paid          float64
# total_tax_payments_amt    float64
# FIPS                       object
# YEAR                        int64
# dtype: object

# %%
taxes.FIPS = taxes.FIPS.astype("str")

# %%
def add_char(string, char, position): 
    # Convert the string to a list of characters 
    string_list = list(string) 
     
    # Insert the character at the specified position 
    string_list.insert(position, str(char)) 
    
    # Join the list back into a string 
    new_string = "".join(string_list)
     
    return new_string 

for i in range(len(taxes.FIPS)): 
    if len(taxes.FIPS[i]) != 5:
        
        taxes.FIPS[i] = add_char(taxes.FIPS[i],0,0)
        
    else: 
        taxes.FIPS[i] = taxes.FIPS[i]
# Out:
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_61737/3162042528.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taxes.FIPS[i] = add_char(taxes.FIPS[i],0,0)
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_61737/3162042528.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taxes.FIPS[i] = taxes.FIPS[i]

# %%
taxes
# Out:
#       Unnamed: 0 STATE             COUNTY  Num_Returns  adj_gross_income  \
# 0              0    AL            Alabama    2162210.0       154268214.0
# 1              1    AL     Autauga County      25720.0         1688218.0
# 2              2    AL     Baldwin County     111140.0         9360157.0
# 3              3    AL     Barbour County       9740.0          448442.0
# 4              4    AL        Bibb County       8230.0          533851.0
# ...          ...   ...                ...          ...               ...
# 3189        3189    WY  Sweetwater County      19530.0         1427418.0
# 3190        3190    WY       Teton County      14860.0         9561613.0
# 3191        3191    WY       Uinta County       9350.0          673690.0
# 3192        3192    WY    Washakie County       3790.0          263135.0
# 3193        3193    WY      Weston County       3190.0          215820.0
#
#       total_income  st_local_income_tax  st_local_gen_sales_tax  \
# ...

# %%
employment
# Out:
#        FIPS  annual_avg_estabs_unclassified  annual_avg_emplvl_unclassified  \
# 0     01000                            14.0                             2.0
# 1     01001                             NaN                             NaN
# 2     01003                             NaN                             NaN
# 3     01005                             NaN                             NaN
# 4     01007                             NaN                             NaN
# ...     ...                             ...                             ...
# 3711  C4962                             NaN                             NaN
# 3712  C4966                            22.0                            45.0
# 3713  C4970                             3.0                             0.0
# 3714  C4974                           109.0                           191.0
# 3715  US000                        346364.0                        295426.0
#
# ...

# %%
taxes = taxes.rename(columns={"YEAR": "YEAR_taxes"})

# %%
taxes.FIPS = taxes.FIPS.astype("str")
employment.FIPS = employment.FIPS.astype("str")

# %%
comb = taxes.merge(employment, on="FIPS", how="outer")
comb
# Out:
#       Unnamed: 0 STATE          COUNTY  Num_Returns  adj_gross_income  \
# 0            0.0    AL         Alabama    2162210.0       154268214.0
# 1            1.0    AL  Autauga County      25720.0         1688218.0
# 2            2.0    AL  Baldwin County     111140.0         9360157.0
# 3            3.0    AL  Barbour County       9740.0          448442.0
# 4            4.0    AL     Bibb County       8230.0          533851.0
# ...          ...   ...             ...          ...               ...
# 3720         NaN   NaN             NaN          NaN               NaN
# 3721         NaN   NaN             NaN          NaN               NaN
# 3722         NaN   NaN             NaN          NaN               NaN
# 3723         NaN   NaN             NaN          NaN               NaN
# 3724         NaN   NaN             NaN          NaN               NaN
#
#       total_income  st_local_income_tax  st_local_gen_sales_tax  \
# ...

# %%
comb.to_csv("combined_unfinished.csv")

# %%
school = pd.read_csv("acgr-sch-sy2020-21-long.csv")
school
# Out:
#        SCHOOL_YEAR        STNAM  FIPST    LEAID ST_LEAID  \
# 0        2020-2021      ALABAMA      1   100005   AL-101
# 1        2020-2021      ALABAMA      1   100005   AL-101
# 2        2020-2021      ALABAMA      1   100005   AL-101
# 3        2020-2021      ALABAMA      1   100005   AL-101
# 4        2020-2021      ALABAMA      1   100005   AL-101
# ...            ...          ...    ...      ...      ...
# 190909   2020-2021  PUERTO RICO     72  7200030    PR-01
# 190910   2020-2021  PUERTO RICO     72  7200030    PR-01
# 190911   2020-2021  PUERTO RICO     72  7200030    PR-01
# 190912   2020-2021  PUERTO RICO     72  7200030    PR-01
# 190913   2020-2021  PUERTO RICO     72  7200030    PR-01
#
#                                       LEANM       NCESSCH     ST_SCHID  \
# 0                          Albertville City   10000500871  AL-101-0020
# 1                          Albertville City   10000500871  AL-101-0020
# ...

# %%
small = school.loc[school['CATEGORY'] == "ALL"]
small = small[["SCHOOL_YEAR", "STNAM", "LEANM", "COHORT", "RATE", "DATE_CUR"]]
small
# Out:
#        SCHOOL_YEAR        STNAM                                LEANM  COHORT  \
# 0        2020-2021      ALABAMA                     Albertville City     385
# 11       2020-2021      ALABAMA                      Marshall County      83
# 19       2020-2021      ALABAMA                      Marshall County     137
# 29       2020-2021      ALABAMA                      Marshall County     104
# 36       2020-2021      ALABAMA                      Marshall County      78
# ...            ...          ...                                  ...     ...
# 190887   2020-2021  PUERTO RICO  PUERTO RICO DEPARTMENT OF EDUCATION      47
# 190892   2020-2021  PUERTO RICO  PUERTO RICO DEPARTMENT OF EDUCATION     164
# 190898   2020-2021  PUERTO RICO  PUERTO RICO DEPARTMENT OF EDUCATION      89
# 190904   2020-2021  PUERTO RICO  PUERTO RICO DEPARTMENT OF EDUCATION     110
# 190909   2020-2021  PUERTO RICO  PUERTO RICO DEPARTMENT OF EDUCATION     147
#
#          RATE DATE_CUR
# ...

# %%
small.to_csv("graduation_capstone.csv")

# %%
hosp = pd.read_csv("Cleaned Data/hospital_capstone.csv")
converter = pd.read_csv("ZIP-COUNTY-FIPS_2017-06.csv")

# %%
hosp["c"] = hosp["STATE"] + hosp["COUNTY"]
hosp
# Out:
#       Unnamed: 0        CITY STATE  ZIP Code             COUNTY  \
# 0              0      DOTHAN    AL     36301     HOUSTON County
# 1              1        BOAZ    AL     35957    MARSHALL County
# 2              2    FLORENCE    AL     35630  LAUDERDALE County
# 3              3         OPP    AL     36467   COVINGTON County
# 4              4     LUVERNE    AL     36049    CRENSHAW County
# ...          ...         ...   ...       ...                ...
# 5420        5420  MIDLOTHIAN    TX     76065       ELLIS County
# 5421        5421   MANSFIELD    TX     76063     TARRANT County
# 5422        5422      HUMBLE    TX     77338      HARRIS County
# 5423        5423  SUGAR LAND    TX     77479   FORT BEND County
# 5424        5424      SACHSE    TX     75048      DALLAS County
#
#      Emergency Services                    c
# 0                   Yes     ALHOUSTON County
# 1                   Yes    ALMARSHALL County
# 2                   Yes  ALLAUDERDALE County
# ...

# %%
for i in range(len(hosp.c)):
    hosp.c[i]=hosp.c[i].lower()
    
hosp
# Out:
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_61737/3200893659.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hosp.c[i]=hosp.c[i].lower()
#       Unnamed: 0        CITY STATE  ZIP Code             COUNTY  \
# 0              0      DOTHAN    AL     36301     HOUSTON County
# 1              1        BOAZ    AL     35957    MARSHALL County
# 2              2    FLORENCE    AL     35630  LAUDERDALE County
# 3              3         OPP    AL     36467   COVINGTON County
# 4              4     LUVERNE    AL     36049    CRENSHAW County
# ...          ...         ...   ...       ...                ...
# 5420        5420  MIDLOTHIAN    TX     76065       ELLIS County
# 5421        5421   MANSFIELD    TX     76063     TARRANT County
# ...

# %%
converter["c"] = converter["STATE"] + converter["COUNTYNAME"]
converter = converter.groupby("COUNTYNAME")
# Out:
#          ZIP         COUNTYNAME STATE  STCOUNTYFP CLASSFP                    c
# 0      36003     Autauga County    AL        1001      H1     ALAutauga County
# 1      36006     Autauga County    AL        1001      H1     ALAutauga County
# 2      36067     Autauga County    AL        1001      H1     ALAutauga County
# 3      36066     Autauga County    AL        1001      H1     ALAutauga County
# 4      36703     Autauga County    AL        1001      H1     ALAutauga County
# ...      ...                ...   ...         ...     ...                  ...
# 52884    850   St. Croix Island    VI       78010      H4   VISt. Croix Island
# 52885    840   St. Croix Island    VI       78010      H4   VISt. Croix Island
# 52886    820   St. Croix Island    VI       78010      H4   VISt. Croix Island
# 52887    830    St. John Island    VI       78020      H4    VISt. John Island
# 52888    802  St. Thomas Island    VI       78030      H4  VISt. Thomas Island
#
# ...

# %%
for i in range(len(converter.c)):
    converter.c[i]=converter.c[i].lower()
    
converter
# Out:
# /var/folders/ql/3twgx7yj36ddmzjqgbpdmthh0000gn/T/ipykernel_61737/2653157441.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   converter.c[i]=converter.c[i].lower()
#          ZIP         COUNTYNAME STATE  STCOUNTYFP CLASSFP                    c
# 0      36003     Autauga County    AL        1001      H1     alautauga county
# 1      36006     Autauga County    AL        1001      H1     alautauga county
# 2      36067     Autauga County    AL        1001      H1     alautauga county
# 3      36066     Autauga County    AL        1001      H1     alautauga county
# 4      36703     Autauga County    AL        1001      H1     alautauga county
# ...      ...                ...   ...         ...     ...                  ...
# ...

# %%
co = converter.merge(hosp, on="c", how="right")
co
# Out:
#             ZIP      COUNTYNAME STATE_x  STCOUNTYFP CLASSFP                 c  \
# 0       36305.0  Houston County      AL      1069.0      H1  alhouston county
# 1       36345.0  Houston County      AL      1069.0      H1  alhouston county
# 2       36321.0  Houston County      AL      1069.0      H1  alhouston county
# 3       36301.0  Houston County      AL      1069.0      H1  alhouston county
# 4       36352.0  Houston County      AL      1069.0      H1  alhouston county
# ...         ...             ...     ...         ...     ...               ...
# 251202  75007.0   Dallas County      TX     48113.0      H1   txdallas county
# 251203  75371.0   Dallas County      TX     48113.0      H1   txdallas county
# 251204  75123.0   Dallas County      TX     48113.0      H1   txdallas county
# 251205  75185.0   Dallas County      TX     48113.0      H1   txdallas county
# 251206  75067.0   Dallas County      TX     48113.0      H1   txdallas county
#
# ...

# %%
school = pd.read_csv("acgr-sch-sy2020-21-long.csv")
small = school.loc[school['CATEGORY'] == "ALL"]
small = small[["SCHOOL_YEAR", "STNAM", "LEANM", "COHORT", "RATE", "DATE_CUR"]]
small
test = small
len(test.RATE[0])
a = test.RATE.value_counts()
a.head(20)
test = test[test.RATE != "PS"]

test.RATE.value_counts().head(20)

# %%
for i in range(len(test.RATE)):
    
    v = list(str(test.RATE[i]))
    if len(v) == 1:
        test.RATE[i] = int(test.RATE[i])
    elif len(v) == 2:
        test.RATE[i] = int(test.RATE[i])
    elif len(v) == 3:
        v = v[-1]
        v = "".join(v)
        test.RATE[i] = int(v)
    elif len(v) == 4:
        v = v[-2:]
        v = "".join(v)
        test.RATE[i] = int(v)
    elif len(v) == 5:
        math = test.RATE[i].split("-")
        math[0] = int(math[0])
        math[1] = int(math[1])
        math = sum(math)/len(math)
        test.RATE[i] = math
        
test

n = 5
mylist = [1,2,3,4,5,6,7,8,9]
newlist = mylist[n:]
[6, 7, 8, 9]

a = "56-80"
b = a.split("-")
b[0] = int(b[0])
b[1] = int(b[1])
sum(b)/len(b)

b = [6, 7, 8, 9]
b[-2:]
